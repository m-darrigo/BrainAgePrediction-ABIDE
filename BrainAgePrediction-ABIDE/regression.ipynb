# %%
'''
Regression Module

This module contains code for performing regression analysis using both linear regression and neural networks.
It includes functions and pipelines for data preprocessing, model training, and evaluation. The main components
include the use of scikit-learn and Keras for building and training regression models.

Note: This module assumes that the necessary libraries such as pandas, matplotlib, scikeras, and keras are installed.

'''

# %%
import pandas as pd
import matplotlib.pyplot as plt
import regression_pipelines as rp
from scikeras.wrappers import KerasRegressor
from keras.callbacks import EarlyStopping
from sklearn.preprocessing import PowerTransformer
from sklearn.decomposition import PCA
from sklearn.pipeline import Pipeline
from keras.optimizers import RMSprop
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# 2024-01-08 20:57:08.638458: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
plt.rcParams.update(
    {
        "axes.grid": True,
        "grid.alpha": 0.5,
        "grid.linestyle": "--"
    }
)

# %% [markdown]
# ## Import data

# %%
df = pd.read_csv("../data/FS_features_ABIDE_males.csv", sep=";")
df = df.set_index("FILE_ID")

# drop target
y = df["AGE_AT_SCAN"].values
df = df.drop(["AGE_AT_SCAN", "SEX"], axis=1).values

# %%
results_regressor = rp.linear_regressor_pipeline(df, y, verbose=1, seed=rp.SEED)
results_regressor.to_csv("best_model_regressor.csv", index=False)
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# Done!

# %%
pd.read_csv("best_model_regressor.csv").head(1).T
# Out:
#                                       0
# mean_fit_time                  0.512901
# std_fit_time                   0.015664
# mean_score_time                0.011489
# std_score_time                 0.000189
# param_model__alpha                    1
# params              {'model__alpha': 1}
# split0_test_score              0.705735
# split1_test_score              0.660429
# split2_test_score              0.701759
# split3_test_score              0.615421
# split4_test_score              0.614307
# mean_test_score                 0.65953
# std_test_score                 0.039774
# rank_test_score                       1
# split0_train_score             0.674544
# split1_train_score             0.673893
# split2_train_score             0.659877
# split3_train_score             0.664543
# split4_train_score             0.683799
# mean_train_score               0.671331
# std_train_score                0.008362

# %% [markdown]
# ## Neural network

# %%
callback = EarlyStopping(
    monitor="val_loss",
    min_delta=0,
    patience=5,
    restore_best_weights=True,
)

# set up MLP model
mlp = KerasRegressor(
    rp.n_layers_feed_forward, 
    epochs=200, 
    loss="mse",
    callbacks=[callback],
    validation_split=0.2,
    nlayers=3,
    hiddens=[2,2,2],
    dropouts=[0.2, 0, 0],
    verbose=0,
)

# %%
results_mlp = rp.neural_network_pipeline(mlp, df, y, niter=100, verbose=3, seed=rp.SEED)
# Out:
# Starting grid search neural_network...
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# [CV 1/5] END mlp__dropouts=[0.  0.  0.3 0.3 0.  0.1], mlp__hiddens=(4, 8, 16, 64, 16, 16), mlp__nlayers=5, mlp__optimizer__learning_rate=0.005;, score=(train=0.707, test=0.629) total time=   1.5s
# [CV 2/5] END mlp__dropouts=[0.  0.  0.3 0.3 0.  0.1], mlp__hiddens=(4, 8, 16, 64, 16, 16), mlp__nlayers=5, mlp__optimizer__learning_rate=0.005;, score=(train=0.738, test=0.710) total time=   1.6s
# [CV 3/5] END mlp__dropouts=[0.  0.  0.3 0.3 0.  0.1], mlp__hiddens=(4, 8, 16, 64, 16, 16), mlp__nlayers=5, mlp__optimizer__learning_rate=0.005;, score=(train=0.701, test=0.625) total time=   1.5s
# [CV 4/5] END mlp__dropouts=[0.  0.  0.3 0.3 0.  0.1], mlp__hiddens=(4, 8, 16, 64, 16, 16), mlp__nlayers=5, mlp__optimizer__learning_rate=0.005;, score=(train=0.664, test=0.616) total time=   1.5s
# [CV 5/5] END mlp__dropouts=[0.  0.  0.3 0.3 0.  0.1], mlp__hiddens=(4, 8, 16, 64, 16, 16), mlp__nlayers=5, mlp__optimizer__learning_rate=0.005;, score=(train=0.653, test=0.662) total time=   1.5s
# [CV 1/5] END mlp__dropouts=[0.2 0.3 0.2 0.  0.3 0. ], mlp__hiddens=(8, 64, 4, 8, 8, 32), mlp__nlayers=4, mlp__optimizer__learning_rate=0.005;, score=(train=0.620, test=0.538) total time=   1.5s
# [CV 2/5] END mlp__dropouts=[0.2 0.3 0.2 0.  0.3 0. ], mlp__hiddens=(8, 64, 4, 8, 8, 32), mlp__nlayers=4, mlp__optimizer__learning_rate=0.005;, score=(train=0.683, test=0.644) total time=   1.5s
# [CV 3/5] END mlp__dropouts=[0.2 0.3 0.2 0.  0.3 0. ], mlp__hiddens=(8, 64, 4, 8, 8, 32), mlp__nlayers=4, mlp__optimizer__learning_rate=0.005;, score=(train=0.719, test=0.655) total time=   1.4s
# [CV 4/5] END mlp__dropouts=[0.2 0.3 0.2 0.  0.3 0. ], mlp__hiddens=(8, 64, 4, 8, 8, 32), mlp__nlayers=4, mlp__optimizer__learning_rate=0.005;, score=(train=0.596, test=0.557) total time=   1.4s
# [CV 5/5] END mlp__dropouts=[0.2 0.3 0.2 0.  0.3 0. ], mlp__hiddens=(8, 64, 4, 8, 8, 32), mlp__nlayers=4, mlp__optimizer__learning_rate=0.005;, score=(train=0.711, test=0.672) total time=   1.6s
# [CV 1/5] END mlp__dropouts=[0.  0.  0.2 0.3 0.  0. ], mlp__hiddens=(16, 8, 64, 64, 32, 4), mlp__nlayers=4, mlp__optimizer__learning_rate=0.005;, score=(train=0.786, test=0.678) total time=   1.4s
# [CV 2/5] END mlp__dropouts=[0.  0.  0.2 0.3 0.  0. ], mlp__hiddens=(16, 8, 64, 64, 32, 4), mlp__nlayers=4, mlp__optimizer__learning_rate=0.005;, score=(train=0.680, test=0.513) total time=   1.4s
# [CV 3/5] END mlp__dropouts=[0.  0.  0.2 0.3 0.  0. ], mlp__hiddens=(16, 8, 64, 64, 32, 4), mlp__nlayers=4, mlp__optimizer__learning_rate=0.005;, score=(train=0.749, test=0.652) total time=   1.3s
# [CV 4/5] END mlp__dropouts=[0.  0.  0.2 0.3 0.  0. ], mlp__hiddens=(16, 8, 64, 64, 32, 4), mlp__nlayers=4, mlp__optimizer__learning_rate=0.005;, score=(train=0.775, test=0.681) total time=   1.4s
# [CV 5/5] END mlp__dropouts=[0.  0.  0.2 0.3 0.  0. ], mlp__hiddens=(16, 8, 64, 64, 32, 4), mlp__nlayers=4, mlp__optimizer__learning_rate=0.005;, score=(train=0.702, test=0.678) total time=   1.3s
# [CV 1/5] END mlp__dropouts=[0.2 0.3 0.2 0.1 0.  0.2], mlp__hiddens=(4, 4, 4, 8, 8, 16), mlp__nlayers=1, mlp__optimizer__learning_rate=0.001;, score=(train=0.564, test=0.468) total time=   4.7s
# [CV 2/5] END mlp__dropouts=[0.2 0.3 0.2 0.1 0.  0.2], mlp__hiddens=(4, 4, 4, 8, 8, 16), mlp__nlayers=1, mlp__optimizer__learning_rate=0.001;, score=(train=0.562, test=0.415) total time=   4.5s
# [CV 3/5] END mlp__dropouts=[0.2 0.3 0.2 0.1 0.  0.2], mlp__hiddens=(4, 4, 4, 8, 8, 16), mlp__nlayers=1, mlp__optimizer__learning_rate=0.001;, score=(train=0.532, test=0.428) total time=   4.5s
# [CV 4/5] END mlp__dropouts=[0.2 0.3 0.2 0.1 0.  0.2], mlp__hiddens=(4, 4, 4, 8, 8, 16), mlp__nlayers=1, mlp__optimizer__learning_rate=0.001;, score=(train=0.558, test=0.511) total time=   5.0s
# [CV 5/5] END mlp__dropouts=[0.2 0.3 0.2 0.1 0.  0.2], mlp__hiddens=(4, 4, 4, 8, 8, 16), mlp__nlayers=1, mlp__optimizer__learning_rate=0.001;, score=(train=0.379, test=0.466) total time=   3.8s
# [CV 1/5] END mlp__dropouts=[0.  0.2 0.  0.  0.1 0.2], mlp__hiddens=(4, 4, 16, 4, 16, 4), mlp__nlayers=4, mlp__optimizer__learning_rate=0.0001;, score=(train=-0.100, test=-0.278) total time=   5.7s
# [CV 2/5] END mlp__dropouts=[0.  0.2 0.  0.  0.1 0.2], mlp__hiddens=(4, 4, 16, 4, 16, 4), mlp__nlayers=4, mlp__optimizer__learning_rate=0.0001;, score=(train=-0.040, test=-0.154) total time=   5.7s
# [CV 3/5] END mlp__dropouts=[0.  0.2 0.  0.  0.1 0.2], mlp__hiddens=(4, 4, 16, 4, 16, 4), mlp__nlayers=4, mlp__optimizer__learning_rate=0.0001;, score=(train=-0.190, test=-0.295) total time=   5.7s
# [CV 4/5] END mlp__dropouts=[0.  0.2 0.  0.  0.1 0.2], mlp__hiddens=(4, 4, 16, 4, 16, 4), mlp__nlayers=4, mlp__optimizer__learning_rate=0.0001;, score=(train=-0.052, test=0.078) total time=   5.7s
# [CV 5/5] END mlp__dropouts=[0.  0.2 0.  0.  0.1 0.2], mlp__hiddens=(4, 4, 16, 4, 16, 4), mlp__nlayers=4, mlp__optimizer__learning_rate=0.0001;, score=(train=-0.175, test=0.012) total time=   5.7s
# [CV 1/5] END mlp__dropouts=[0.  0.3 0.1 0.1 0.  0.1], mlp__hiddens=(8, 8, 8, 32, 16, 64), mlp__nlayers=3, mlp__optimizer__learning_rate=0.001;, score=(train=0.325, test=0.214) total time=   1.8s
# [CV 2/5] END mlp__dropouts=[0.  0.3 0.1 0.1 0.  0.1], mlp__hiddens=(8, 8, 8, 32, 16, 64), mlp__nlayers=3, mlp__optimizer__learning_rate=0.001;, score=(train=0.590, test=0.456) total time=   2.5s
# [CV 3/5] END mlp__dropouts=[0.  0.3 0.1 0.1 0.  0.1], mlp__hiddens=(8, 8, 8, 32, 16, 64), mlp__nlayers=3, mlp__optimizer__learning_rate=0.001;, score=(train=0.496, test=0.423) total time=   2.3s
# [CV 4/5] END mlp__dropouts=[0.  0.3 0.1 0.1 0.  0.1], mlp__hiddens=(8, 8, 8, 32, 16, 64), mlp__nlayers=3, mlp__optimizer__learning_rate=0.001;, score=(train=0.605, test=0.574) total time=   2.6s
# [CV 5/5] END mlp__dropouts=[0.  0.3 0.1 0.1 0.  0.1], mlp__hiddens=(8, 8, 8, 32, 16, 64), mlp__nlayers=3, mlp__optimizer__learning_rate=0.001;, score=(train=0.524, test=0.562) total time=   2.4s
# [CV 1/5] END mlp__dropouts=[0.3 0.3 0.  0.2 0.3 0. ], mlp__hiddens=(8, 4, 64, 4, 4, 64), mlp__nlayers=6, mlp__optimizer__learning_rate=0.001;, score=(train=0.342, test=0.328) total time=   2.2s
# [CV 2/5] END mlp__dropouts=[0.3 0.3 0.  0.2 0.3 0. ], mlp__hiddens=(8, 4, 64, 4, 4, 64), mlp__nlayers=6, mlp__optimizer__learning_rate=0.001;, score=(train=0.282, test=0.295) total time=   2.2s
# [CV 3/5] END mlp__dropouts=[0.3 0.3 0.  0.2 0.3 0. ], mlp__hiddens=(8, 4, 64, 4, 4, 64), mlp__nlayers=6, mlp__optimizer__learning_rate=0.001;, score=(train=0.331, test=0.262) total time=   2.2s
# [CV 4/5] END mlp__dropouts=[0.3 0.3 0.  0.2 0.3 0. ], mlp__hiddens=(8, 4, 64, 4, 4, 64), mlp__nlayers=6, mlp__optimizer__learning_rate=0.001;, score=(train=0.340, test=0.264) total time=   2.2s
# [CV 5/5] END mlp__dropouts=[0.3 0.3 0.  0.2 0.3 0. ], mlp__hiddens=(8, 4, 64, 4, 4, 64), mlp__nlayers=6, mlp__optimizer__learning_rate=0.001;, score=(train=-0.105, test=-0.147) total time=   1.8s
# [CV 1/5] END mlp__dropouts=[0.2 0.2 0.  0.  0.2 0.1], mlp__hiddens=(32, 16, 32, 32, 32, 8), mlp__nlayers=2, mlp__optimizer__learning_rate=0.005;, score=(train=0.757, test=0.606) total time=   1.5s
# [CV 2/5] END mlp__dropouts=[0.2 0.2 0.  0.  0.2 0.1], mlp__hiddens=(32, 16, 32, 32, 32, 8), mlp__nlayers=2, mlp__optimizer__learning_rate=0.005;, score=(train=0.766, test=0.672) total time=   1.6s
# [CV 3/5] END mlp__dropouts=[0.2 0.2 0.  0.  0.2 0.1], mlp__hiddens=(32, 16, 32, 32, 32, 8), mlp__nlayers=2, mlp__optimizer__learning_rate=0.005;, score=(train=0.770, test=0.708) total time=   1.7s
# [CV 4/5] END mlp__dropouts=[0.2 0.2 0.  0.  0.2 0.1], mlp__hiddens=(32, 16, 32, 32, 32, 8), mlp__nlayers=2, mlp__optimizer__learning_rate=0.005;, score=(train=0.738, test=0.682) total time=   1.4s
# [CV 5/5] END mlp__dropouts=[0.2 0.2 0.  0.  0.2 0.1], mlp__hiddens=(32, 16, 32, 32, 32, 8), mlp__nlayers=2, mlp__optimizer__learning_rate=0.005;, score=(train=0.753, test=0.701) total time=   1.5s
# [CV 1/5] END mlp__dropouts=[0.  0.3 0.  0.1 0.3 0. ], mlp__hiddens=(8, 16, 32, 8, 64, 32), mlp__nlayers=6, mlp__optimizer__learning_rate=0.0001;, score=(train=0.478, test=0.392) total time=   5.5s
# [CV 2/5] END mlp__dropouts=[0.  0.3 0.  0.1 0.3 0. ], mlp__hiddens=(8, 16, 32, 8, 64, 32), mlp__nlayers=6, mlp__optimizer__learning_rate=0.0001;, score=(train=0.026, test=-0.024) total time=   3.6s
# [CV 3/5] END mlp__dropouts=[0.  0.3 0.  0.1 0.3 0. ], mlp__hiddens=(8, 16, 32, 8, 64, 32), mlp__nlayers=6, mlp__optimizer__learning_rate=0.0001;, score=(train=0.276, test=0.064) total time=   4.3s
# [CV 4/5] END mlp__dropouts=[0.  0.3 0.  0.1 0.3 0. ], mlp__hiddens=(8, 16, 32, 8, 64, 32), mlp__nlayers=6, mlp__optimizer__learning_rate=0.0001;, score=(train=0.322, test=0.295) total time=   4.6s
# [CV 5/5] END mlp__dropouts=[0.  0.3 0.  0.1 0.3 0. ], mlp__hiddens=(8, 16, 32, 8, 64, 32), mlp__nlayers=6, mlp__optimizer__learning_rate=0.0001;, score=(train=0.014, test=0.031) total time=   3.7s
# [CV 1/5] END mlp__dropouts=[0.  0.  0.  0.1 0.  0. ], mlp__hiddens=(4, 64, 8, 4, 64, 16), mlp__nlayers=5, mlp__optimizer__learning_rate=0.005;, score=(train=0.748, test=0.650) total time=   1.5s
# [CV 2/5] END mlp__dropouts=[0.  0.  0.  0.1 0.  0. ], mlp__hiddens=(4, 64, 8, 4, 64, 16), mlp__nlayers=5, mlp__optimizer__learning_rate=0.005;, score=(train=0.717, test=0.688) total time=   1.4s
# [CV 3/5] END mlp__dropouts=[0.  0.  0.  0.1 0.  0. ], mlp__hiddens=(4, 64, 8, 4, 64, 16), mlp__nlayers=5, mlp__optimizer__learning_rate=0.005;, score=(train=0.724, test=0.725) total time=   1.7s
# [CV 4/5] END mlp__dropouts=[0.  0.  0.  0.1 0.  0. ], mlp__hiddens=(4, 64, 8, 4, 64, 16), mlp__nlayers=5, mlp__optimizer__learning_rate=0.005;, score=(train=0.750, test=0.722) total time=   1.5s
# [CV 5/5] END mlp__dropouts=[0.  0.  0.  0.1 0.  0. ], mlp__hiddens=(4, 64, 8, 4, 64, 16), mlp__nlayers=5, mlp__optimizer__learning_rate=0.005;, score=(train=0.754, test=0.718) total time=   1.7s
# [CV 1/5] END mlp__dropouts=[0.2 0.  0.2 0.1 0.1 0. ], mlp__hiddens=(16, 16, 32, 64, 16, 16), mlp__nlayers=3, mlp__optimizer__learning_rate=0.005;, score=(train=0.732, test=0.609) total time=   1.4s
# [CV 2/5] END mlp__dropouts=[0.2 0.  0.2 0.1 0.1 0. ], mlp__hiddens=(16, 16, 32, 64, 16, 16), mlp__nlayers=3, mlp__optimizer__learning_rate=0.005;, score=(train=0.652, test=0.500) total time=   1.2s
# [CV 3/5] END mlp__dropouts=[0.2 0.  0.2 0.1 0.1 0. ], mlp__hiddens=(16, 16, 32, 64, 16, 16), mlp__nlayers=3, mlp__optimizer__learning_rate=0.005;, score=(train=0.732, test=0.658) total time=   1.4s
# [CV 4/5] END mlp__dropouts=[0.2 0.  0.2 0.1 0.1 0. ], mlp__hiddens=(16, 16, 32, 64, 16, 16), mlp__nlayers=3, mlp__optimizer__learning_rate=0.005;, score=(train=0.742, test=0.674) total time=   1.4s
# [CV 5/5] END mlp__dropouts=[0.2 0.  0.2 0.1 0.1 0. ], mlp__hiddens=(16, 16, 32, 64, 16, 16), mlp__nlayers=3, mlp__optimizer__learning_rate=0.005;, score=(train=0.772, test=0.716) total time=   1.5s
# [CV 1/5] END mlp__dropouts=[0.3 0.2 0.1 0.1 0.  0.3], mlp__hiddens=(4, 16, 16, 32, 4, 8), mlp__nlayers=4, mlp__optimizer__learning_rate=0.001;, score=(train=0.249, test=0.202) total time=   1.7s
# [CV 2/5] END mlp__dropouts=[0.3 0.2 0.1 0.1 0.  0.3], mlp__hiddens=(4, 16, 16, 32, 4, 8), mlp__nlayers=4, mlp__optimizer__learning_rate=0.001;, score=(train=0.473, test=0.475) total time=   2.3s
# [CV 3/5] END mlp__dropouts=[0.3 0.2 0.1 0.1 0.  0.3], mlp__hiddens=(4, 16, 16, 32, 4, 8), mlp__nlayers=4, mlp__optimizer__learning_rate=0.001;, score=(train=0.346, test=0.221) total time=   1.8s
# [CV 4/5] END mlp__dropouts=[0.3 0.2 0.1 0.1 0.  0.3], mlp__hiddens=(4, 16, 16, 32, 4, 8), mlp__nlayers=4, mlp__optimizer__learning_rate=0.001;, score=(train=0.470, test=0.471) total time=   2.3s
# [CV 5/5] END mlp__dropouts=[0.3 0.2 0.1 0.1 0.  0.3], mlp__hiddens=(4, 16, 16, 32, 4, 8), mlp__nlayers=4, mlp__optimizer__learning_rate=0.001;, score=(train=0.320, test=0.249) total time=   2.0s
# [CV 1/5] END mlp__dropouts=[0.3 0.  0.  0.  0.1 0. ], mlp__hiddens=(16, 64, 32, 64, 8, 4), mlp__nlayers=6, mlp__optimizer__learning_rate=0.005;, score=(train=0.730, test=0.648) total time=   1.6s
# [CV 2/5] END mlp__dropouts=[0.3 0.  0.  0.  0.1 0. ], mlp__hiddens=(16, 64, 32, 64, 8, 4), mlp__nlayers=6, mlp__optimizer__learning_rate=0.005;, score=(train=0.648, test=0.565) total time=   1.4s
# [CV 3/5] END mlp__dropouts=[0.3 0.  0.  0.  0.1 0. ], mlp__hiddens=(16, 64, 32, 64, 8, 4), mlp__nlayers=6, mlp__optimizer__learning_rate=0.005;, score=(train=0.394, test=0.134) total time=   1.3s
# [CV 4/5] END mlp__dropouts=[0.3 0.  0.  0.  0.1 0. ], mlp__hiddens=(16, 64, 32, 64, 8, 4), mlp__nlayers=6, mlp__optimizer__learning_rate=0.005;, score=(train=0.734, test=0.687) total time=   1.5s
# [CV 5/5] END mlp__dropouts=[0.3 0.  0.  0.  0.1 0. ], mlp__hiddens=(16, 64, 32, 64, 8, 4), mlp__nlayers=6, mlp__optimizer__learning_rate=0.005;, score=(train=0.766, test=0.687) total time=   1.6s
# [CV 1/5] END mlp__dropouts=[0.  0.  0.2 0.  0.2 0. ], mlp__hiddens=(32, 8, 64, 32, 8, 16), mlp__nlayers=5, mlp__optimizer__learning_rate=0.001;, score=(train=0.667, test=0.541) total time=   1.5s
# [CV 2/5] END mlp__dropouts=[0.  0.  0.2 0.  0.2 0. ], mlp__hiddens=(32, 8, 64, 32, 8, 16), mlp__nlayers=5, mlp__optimizer__learning_rate=0.001;, score=(train=0.571, test=0.345) total time=   1.5s
# [CV 3/5] END mlp__dropouts=[0.  0.  0.2 0.  0.2 0. ], mlp__hiddens=(32, 8, 64, 32, 8, 16), mlp__nlayers=5, mlp__optimizer__learning_rate=0.001;, score=(train=0.719, test=0.616) total time=   1.8s
# [CV 4/5] END mlp__dropouts=[0.  0.  0.2 0.  0.2 0. ], mlp__hiddens=(32, 8, 64, 32, 8, 16), mlp__nlayers=5, mlp__optimizer__learning_rate=0.001;, score=(train=0.705, test=0.646) total time=   1.8s
# [CV 5/5] END mlp__dropouts=[0.  0.  0.2 0.  0.2 0. ], mlp__hiddens=(32, 8, 64, 32, 8, 16), mlp__nlayers=5, mlp__optimizer__learning_rate=0.001;, score=(train=0.719, test=0.665) total time=   2.0s
# [CV 1/5] END mlp__dropouts=[0.  0.2 0.3 0.1 0.  0.2], mlp__hiddens=(8, 32, 4, 16, 16, 8), mlp__nlayers=1, mlp__optimizer__learning_rate=0.005;, score=(train=0.770, test=0.627) total time=   2.1s
# [CV 2/5] END mlp__dropouts=[0.  0.2 0.3 0.1 0.  0.2], mlp__hiddens=(8, 32, 4, 16, 16, 8), mlp__nlayers=1, mlp__optimizer__learning_rate=0.005;, score=(train=0.735, test=0.639) total time=   1.8s
# [CV 3/5] END mlp__dropouts=[0.  0.2 0.3 0.1 0.  0.2], mlp__hiddens=(8, 32, 4, 16, 16, 8), mlp__nlayers=1, mlp__optimizer__learning_rate=0.005;, score=(train=0.753, test=0.652) total time=   2.1s
# [CV 4/5] END mlp__dropouts=[0.  0.2 0.3 0.1 0.  0.2], mlp__hiddens=(8, 32, 4, 16, 16, 8), mlp__nlayers=1, mlp__optimizer__learning_rate=0.005;, score=(train=0.760, test=0.730) total time=   1.9s
# [CV 5/5] END mlp__dropouts=[0.  0.2 0.3 0.1 0.  0.2], mlp__hiddens=(8, 32, 4, 16, 16, 8), mlp__nlayers=1, mlp__optimizer__learning_rate=0.005;, score=(train=0.701, test=0.678) total time=   1.5s
# [CV 1/5] END mlp__dropouts=[0.  0.3 0.  0.1 0.  0.1], mlp__hiddens=(8, 8, 8, 32, 64, 8), mlp__nlayers=6, mlp__optimizer__learning_rate=0.005;, score=(train=0.697, test=0.602) total time=   1.8s
# [CV 2/5] END mlp__dropouts=[0.  0.3 0.  0.1 0.  0.1], mlp__hiddens=(8, 8, 8, 32, 64, 8), mlp__nlayers=6, mlp__optimizer__learning_rate=0.005;, score=(train=0.750, test=0.699) total time=   1.6s
# [CV 3/5] END mlp__dropouts=[0.  0.3 0.  0.1 0.  0.1], mlp__hiddens=(8, 8, 8, 32, 64, 8), mlp__nlayers=6, mlp__optimizer__learning_rate=0.005;, score=(train=0.650, test=0.602) total time=   1.5s
# [CV 4/5] END mlp__dropouts=[0.  0.3 0.  0.1 0.  0.1], mlp__hiddens=(8, 8, 8, 32, 64, 8), mlp__nlayers=6, mlp__optimizer__learning_rate=0.005;, score=(train=0.638, test=0.597) total time=   1.7s
# [CV 5/5] END mlp__dropouts=[0.  0.3 0.  0.1 0.  0.1], mlp__hiddens=(8, 8, 8, 32, 64, 8), mlp__nlayers=6, mlp__optimizer__learning_rate=0.005;, score=(train=0.718, test=0.642) total time=   1.8s
# [CV 1/5] END mlp__dropouts=[0.  0.3 0.2 0.  0.3 0.2], mlp__hiddens=(64, 16, 4, 16, 16, 16), mlp__nlayers=6, mlp__optimizer__learning_rate=0.005;, score=(train=0.684, test=0.581) total time=   1.7s
# [CV 2/5] END mlp__dropouts=[0.  0.3 0.2 0.  0.3 0.2], mlp__hiddens=(64, 16, 4, 16, 16, 16), mlp__nlayers=6, mlp__optimizer__learning_rate=0.005;, score=(train=0.573, test=0.498) total time=   1.4s
# [CV 3/5] END mlp__dropouts=[0.  0.3 0.2 0.  0.3 0.2], mlp__hiddens=(64, 16, 4, 16, 16, 16), mlp__nlayers=6, mlp__optimizer__learning_rate=0.005;, score=(train=0.763, test=0.753) total time=   1.6s
# [CV 4/5] END mlp__dropouts=[0.  0.3 0.2 0.  0.3 0.2], mlp__hiddens=(64, 16, 4, 16, 16, 16), mlp__nlayers=6, mlp__optimizer__learning_rate=0.005;, score=(train=0.309, test=0.270) total time=   1.5s
# [CV 5/5] END mlp__dropouts=[0.  0.3 0.2 0.  0.3 0.2], mlp__hiddens=(64, 16, 4, 16, 16, 16), mlp__nlayers=6, mlp__optimizer__learning_rate=0.005;, score=(train=0.666, test=0.611) total time=   1.5s
# [CV 1/5] END mlp__dropouts=[0.2 0.2 0.3 0.  0.3 0. ], mlp__hiddens=(4, 16, 64, 64, 8, 8), mlp__nlayers=1, mlp__optimizer__learning_rate=0.0001;, score=(train=-3.431, test=-3.605) total time=   5.4s
# [CV 2/5] END mlp__dropouts=[0.2 0.2 0.3 0.  0.3 0. ], mlp__hiddens=(4, 16, 64, 64, 8, 8), mlp__nlayers=1, mlp__optimizer__learning_rate=0.0001;, score=(train=-3.378, test=-4.293) total time=   5.6s
# [CV 3/5] END mlp__dropouts=[0.2 0.2 0.3 0.  0.3 0. ], mlp__hiddens=(4, 16, 64, 64, 8, 8), mlp__nlayers=1, mlp__optimizer__learning_rate=0.0001;, score=(train=-3.526, test=-3.175) total time=   5.4s
# [CV 4/5] END mlp__dropouts=[0.2 0.2 0.3 0.  0.3 0. ], mlp__hiddens=(4, 16, 64, 64, 8, 8), mlp__nlayers=1, mlp__optimizer__learning_rate=0.0001;, score=(train=-3.580, test=-3.682) total time=   5.3s
# [CV 5/5] END mlp__dropouts=[0.2 0.2 0.3 0.  0.3 0. ], mlp__hiddens=(4, 16, 64, 64, 8, 8), mlp__nlayers=1, mlp__optimizer__learning_rate=0.0001;, score=(train=-3.604, test=-3.288) total time=   5.2s
# [CV 1/5] END mlp__dropouts=[0. 0. 0. 0. 0. 0.], mlp__hiddens=(64, 64, 8, 4, 64, 64), mlp__nlayers=1, mlp__optimizer__learning_rate=0.001;, score=(train=0.781, test=0.622) total time=   1.8s
# [CV 2/5] END mlp__dropouts=[0. 0. 0. 0. 0. 0.], mlp__hiddens=(64, 64, 8, 4, 64, 64), mlp__nlayers=1, mlp__optimizer__learning_rate=0.001;, score=(train=0.695, test=0.557) total time=   1.5s
# [CV 3/5] END mlp__dropouts=[0. 0. 0. 0. 0. 0.], mlp__hiddens=(64, 64, 8, 4, 64, 64), mlp__nlayers=1, mlp__optimizer__learning_rate=0.001;, score=(train=0.772, test=0.680) total time=   1.8s
# [CV 4/5] END mlp__dropouts=[0. 0. 0. 0. 0. 0.], mlp__hiddens=(64, 64, 8, 4, 64, 64), mlp__nlayers=1, mlp__optimizer__learning_rate=0.001;, score=(train=0.756, test=0.709) total time=   1.8s
# [CV 5/5] END mlp__dropouts=[0. 0. 0. 0. 0. 0.], mlp__hiddens=(64, 64, 8, 4, 64, 64), mlp__nlayers=1, mlp__optimizer__learning_rate=0.001;, score=(train=0.742, test=0.697) total time=   1.7s
# [CV 1/5] END mlp__dropouts=[0.2 0.  0.  0.  0.2 0.2], mlp__hiddens=(64, 32, 64, 16, 32, 32), mlp__nlayers=4, mlp__optimizer__learning_rate=0.005;, score=(train=0.754, test=0.629) total time=   1.4s
# [CV 2/5] END mlp__dropouts=[0.2 0.  0.  0.  0.2 0.2], mlp__hiddens=(64, 32, 64, 16, 32, 32), mlp__nlayers=4, mlp__optimizer__learning_rate=0.005;, score=(train=0.718, test=0.539) total time=   1.3s
# [CV 3/5] END mlp__dropouts=[0.2 0.  0.  0.  0.2 0.2], mlp__hiddens=(64, 32, 64, 16, 32, 32), mlp__nlayers=4, mlp__optimizer__learning_rate=0.005;, score=(train=0.754, test=0.666) total time=   1.4s
# [CV 4/5] END mlp__dropouts=[0.2 0.  0.  0.  0.2 0.2], mlp__hiddens=(64, 32, 64, 16, 32, 32), mlp__nlayers=4, mlp__optimizer__learning_rate=0.005;, score=(train=0.750, test=0.677) total time=   1.4s
# [CV 5/5] END mlp__dropouts=[0.2 0.  0.  0.  0.2 0.2], mlp__hiddens=(64, 32, 64, 16, 32, 32), mlp__nlayers=4, mlp__optimizer__learning_rate=0.005;, score=(train=0.754, test=0.682) total time=   1.3s
# [CV 1/5] END mlp__dropouts=[0.1 0.  0.3 0.  0.1 0. ], mlp__hiddens=(4, 8, 32, 16, 32, 16), mlp__nlayers=1, mlp__optimizer__learning_rate=0.005;, score=(train=0.728, test=0.624) total time=   2.0s
# [CV 2/5] END mlp__dropouts=[0.1 0.  0.3 0.  0.1 0. ], mlp__hiddens=(4, 8, 32, 16, 32, 16), mlp__nlayers=1, mlp__optimizer__learning_rate=0.005;, score=(train=0.694, test=0.680) total time=   2.4s
# [CV 3/5] END mlp__dropouts=[0.1 0.  0.3 0.  0.1 0. ], mlp__hiddens=(4, 8, 32, 16, 32, 16), mlp__nlayers=1, mlp__optimizer__learning_rate=0.005;, score=(train=0.680, test=0.642) total time=   2.2s
# [CV 4/5] END mlp__dropouts=[0.1 0.  0.3 0.  0.1 0. ], mlp__hiddens=(4, 8, 32, 16, 32, 16), mlp__nlayers=1, mlp__optimizer__learning_rate=0.005;, score=(train=0.636, test=0.585) total time=   1.9s
# [CV 5/5] END mlp__dropouts=[0.1 0.  0.3 0.  0.1 0. ], mlp__hiddens=(4, 8, 32, 16, 32, 16), mlp__nlayers=1, mlp__optimizer__learning_rate=0.005;, score=(train=0.587, test=0.633) total time=   1.8s
# [CV 1/5] END mlp__dropouts=[0.3 0.  0.3 0.  0.1 0.2], mlp__hiddens=(8, 8, 16, 16, 16, 16), mlp__nlayers=2, mlp__optimizer__learning_rate=0.001;, score=(train=0.667, test=0.594) total time=   2.9s
# [CV 2/5] END mlp__dropouts=[0.3 0.  0.3 0.  0.1 0.2], mlp__hiddens=(8, 8, 16, 16, 16, 16), mlp__nlayers=2, mlp__optimizer__learning_rate=0.001;, score=(train=0.620, test=0.489) total time=   2.6s
# [CV 3/5] END mlp__dropouts=[0.3 0.  0.3 0.  0.1 0.2], mlp__hiddens=(8, 8, 16, 16, 16, 16), mlp__nlayers=2, mlp__optimizer__learning_rate=0.001;, score=(train=0.673, test=0.625) total time=   2.9s
# [CV 4/5] END mlp__dropouts=[0.3 0.  0.3 0.  0.1 0.2], mlp__hiddens=(8, 8, 16, 16, 16, 16), mlp__nlayers=2, mlp__optimizer__learning_rate=0.001;, score=(train=0.634, test=0.613) total time=   2.7s
# [CV 5/5] END mlp__dropouts=[0.3 0.  0.3 0.  0.1 0.2], mlp__hiddens=(8, 8, 16, 16, 16, 16), mlp__nlayers=2, mlp__optimizer__learning_rate=0.001;, score=(train=0.556, test=0.587) total time=   2.2s
# [CV 1/5] END mlp__dropouts=[0.1 0.1 0.  0.3 0.3 0.3], mlp__hiddens=(16, 32, 32, 16, 16, 32), mlp__nlayers=2, mlp__optimizer__learning_rate=0.001;, score=(train=0.753, test=0.653) total time=   2.1s
# [CV 2/5] END mlp__dropouts=[0.1 0.1 0.  0.3 0.3 0.3], mlp__hiddens=(16, 32, 32, 16, 16, 32), mlp__nlayers=2, mlp__optimizer__learning_rate=0.001;, score=(train=0.725, test=0.605) total time=   2.0s
# [CV 3/5] END mlp__dropouts=[0.1 0.1 0.  0.3 0.3 0.3], mlp__hiddens=(16, 32, 32, 16, 16, 32), mlp__nlayers=2, mlp__optimizer__learning_rate=0.001;, score=(train=0.745, test=0.670) total time=   2.1s
# [CV 4/5] END mlp__dropouts=[0.1 0.1 0.  0.3 0.3 0.3], mlp__hiddens=(16, 32, 32, 16, 16, 32), mlp__nlayers=2, mlp__optimizer__learning_rate=0.001;, score=(train=0.717, test=0.674) total time=   1.9s
# [CV 5/5] END mlp__dropouts=[0.1 0.1 0.  0.3 0.3 0.3], mlp__hiddens=(16, 32, 32, 16, 16, 32), mlp__nlayers=2, mlp__optimizer__learning_rate=0.001;, score=(train=0.755, test=0.723) total time=   2.3s
# [CV 1/5] END mlp__dropouts=[0.2 0.1 0.1 0.  0.1 0.2], mlp__hiddens=(64, 64, 4, 32, 64, 4), mlp__nlayers=1, mlp__optimizer__learning_rate=0.0001;, score=(train=0.657, test=0.593) total time=   5.4s
# [CV 2/5] END mlp__dropouts=[0.2 0.1 0.1 0.  0.1 0.2], mlp__hiddens=(64, 64, 4, 32, 64, 4), mlp__nlayers=1, mlp__optimizer__learning_rate=0.0001;, score=(train=0.641, test=0.509) total time=   5.3s
# [CV 3/5] END mlp__dropouts=[0.2 0.1 0.1 0.  0.1 0.2], mlp__hiddens=(64, 64, 4, 32, 64, 4), mlp__nlayers=1, mlp__optimizer__learning_rate=0.0001;, score=(train=0.635, test=0.520) total time=   5.3s
# [CV 4/5] END mlp__dropouts=[0.2 0.1 0.1 0.  0.1 0.2], mlp__hiddens=(64, 64, 4, 32, 64, 4), mlp__nlayers=1, mlp__optimizer__learning_rate=0.0001;, score=(train=0.632, test=0.608) total time=   5.3s
# [CV 5/5] END mlp__dropouts=[0.2 0.1 0.1 0.  0.1 0.2], mlp__hiddens=(64, 64, 4, 32, 64, 4), mlp__nlayers=1, mlp__optimizer__learning_rate=0.0001;, score=(train=0.629, test=0.667) total time=   5.3s
# [CV 1/5] END mlp__dropouts=[0.3 0.  0.3 0.  0.1 0.3], mlp__hiddens=(16, 16, 4, 32, 8, 16), mlp__nlayers=2, mlp__optimizer__learning_rate=0.005;, score=(train=0.733, test=0.650) total time=   1.3s
# [CV 2/5] END mlp__dropouts=[0.3 0.  0.3 0.  0.1 0.3], mlp__hiddens=(16, 16, 4, 32, 8, 16), mlp__nlayers=2, mlp__optimizer__learning_rate=0.005;, score=(train=0.616, test=0.463) total time=   1.2s
# [CV 3/5] END mlp__dropouts=[0.3 0.  0.3 0.  0.1 0.3], mlp__hiddens=(16, 16, 4, 32, 8, 16), mlp__nlayers=2, mlp__optimizer__learning_rate=0.005;, score=(train=0.708, test=0.667) total time=   1.3s
# [CV 4/5] END mlp__dropouts=[0.3 0.  0.3 0.  0.1 0.3], mlp__hiddens=(16, 16, 4, 32, 8, 16), mlp__nlayers=2, mlp__optimizer__learning_rate=0.005;, score=(train=0.701, test=0.658) total time=   1.2s
# [CV 5/5] END mlp__dropouts=[0.3 0.  0.3 0.  0.1 0.3], mlp__hiddens=(16, 16, 4, 32, 8, 16), mlp__nlayers=2, mlp__optimizer__learning_rate=0.005;, score=(train=0.750, test=0.736) total time=   1.4s
# [CV 1/5] END mlp__dropouts=[0.1 0.3 0.2 0.2 0.1 0.2], mlp__hiddens=(32, 32, 8, 8, 4, 8), mlp__nlayers=5, mlp__optimizer__learning_rate=0.005;, score=(train=0.603, test=0.469) total time=   1.6s
# [CV 2/5] END mlp__dropouts=[0.1 0.3 0.2 0.2 0.1 0.2], mlp__hiddens=(32, 32, 8, 8, 4, 8), mlp__nlayers=5, mlp__optimizer__learning_rate=0.005;, score=(train=0.585, test=0.491) total time=   1.4s
# [CV 3/5] END mlp__dropouts=[0.1 0.3 0.2 0.2 0.1 0.2], mlp__hiddens=(32, 32, 8, 8, 4, 8), mlp__nlayers=5, mlp__optimizer__learning_rate=0.005;, score=(train=0.711, test=0.645) total time=   1.7s
# [CV 4/5] END mlp__dropouts=[0.1 0.3 0.2 0.2 0.1 0.2], mlp__hiddens=(32, 32, 8, 8, 4, 8), mlp__nlayers=5, mlp__optimizer__learning_rate=0.005;, score=(train=0.676, test=0.633) total time=   1.6s
# [CV 5/5] END mlp__dropouts=[0.1 0.3 0.2 0.2 0.1 0.2], mlp__hiddens=(32, 32, 8, 8, 4, 8), mlp__nlayers=5, mlp__optimizer__learning_rate=0.005;, score=(train=0.738, test=0.710) total time=   1.6s
# [CV 1/5] END mlp__dropouts=[0.  0.2 0.3 0.  0.  0.2], mlp__hiddens=(16, 32, 16, 64, 8, 16), mlp__nlayers=5, mlp__optimizer__learning_rate=0.001;, score=(train=0.533, test=0.406) total time=   1.7s
# [CV 2/5] END mlp__dropouts=[0.  0.2 0.3 0.  0.  0.2], mlp__hiddens=(16, 32, 16, 64, 8, 16), mlp__nlayers=5, mlp__optimizer__learning_rate=0.001;, score=(train=0.515, test=0.433) total time=   1.5s
# [CV 3/5] END mlp__dropouts=[0.  0.2 0.3 0.  0.  0.2], mlp__hiddens=(16, 32, 16, 64, 8, 16), mlp__nlayers=5, mlp__optimizer__learning_rate=0.001;, score=(train=0.578, test=0.407) total time=   1.5s
# [CV 4/5] END mlp__dropouts=[0.  0.2 0.3 0.  0.  0.2], mlp__hiddens=(16, 32, 16, 64, 8, 16), mlp__nlayers=5, mlp__optimizer__learning_rate=0.001;, score=(train=0.422, test=0.350) total time=   1.5s
# [CV 5/5] END mlp__dropouts=[0.  0.2 0.3 0.  0.  0.2], mlp__hiddens=(16, 32, 16, 64, 8, 16), mlp__nlayers=5, mlp__optimizer__learning_rate=0.001;, score=(train=0.552, test=0.569) total time=   1.6s
# [CV 1/5] END mlp__dropouts=[0.2 0.1 0.  0.1 0.1 0.3], mlp__hiddens=(4, 32, 4, 16, 32, 16), mlp__nlayers=2, mlp__optimizer__learning_rate=0.005;, score=(train=0.738, test=0.659) total time=   1.3s
# [CV 2/5] END mlp__dropouts=[0.2 0.1 0.  0.1 0.1 0.3], mlp__hiddens=(4, 32, 4, 16, 32, 16), mlp__nlayers=2, mlp__optimizer__learning_rate=0.005;, score=(train=0.747, test=0.758) total time=   1.5s
# [CV 3/5] END mlp__dropouts=[0.2 0.1 0.  0.1 0.1 0.3], mlp__hiddens=(4, 32, 4, 16, 32, 16), mlp__nlayers=2, mlp__optimizer__learning_rate=0.005;, score=(train=0.702, test=0.664) total time=   1.5s
# [CV 4/5] END mlp__dropouts=[0.2 0.1 0.  0.1 0.1 0.3], mlp__hiddens=(4, 32, 4, 16, 32, 16), mlp__nlayers=2, mlp__optimizer__learning_rate=0.005;, score=(train=0.696, test=0.684) total time=   1.3s
# [CV 5/5] END mlp__dropouts=[0.2 0.1 0.  0.1 0.1 0.3], mlp__hiddens=(4, 32, 4, 16, 32, 16), mlp__nlayers=2, mlp__optimizer__learning_rate=0.005;, score=(train=0.748, test=0.718) total time=   1.6s
# [CV 1/5] END mlp__dropouts=[0.  0.2 0.  0.  0.  0.3], mlp__hiddens=(16, 64, 4, 8, 4, 64), mlp__nlayers=1, mlp__optimizer__learning_rate=0.0001;, score=(train=0.349, test=0.282) total time=   5.2s
# [CV 2/5] END mlp__dropouts=[0.  0.2 0.  0.  0.  0.3], mlp__hiddens=(16, 64, 4, 8, 4, 64), mlp__nlayers=1, mlp__optimizer__learning_rate=0.0001;, score=(train=0.355, test=0.112) total time=   5.2s
# [CV 3/5] END mlp__dropouts=[0.  0.2 0.  0.  0.  0.3], mlp__hiddens=(16, 64, 4, 8, 4, 64), mlp__nlayers=1, mlp__optimizer__learning_rate=0.0001;, score=(train=0.373, test=0.259) total time=   5.2s
# [CV 4/5] END mlp__dropouts=[0.  0.2 0.  0.  0.  0.3], mlp__hiddens=(16, 64, 4, 8, 4, 64), mlp__nlayers=1, mlp__optimizer__learning_rate=0.0001;, score=(train=0.345, test=0.351) total time=   5.2s
# [CV 5/5] END mlp__dropouts=[0.  0.2 0.  0.  0.  0.3], mlp__hiddens=(16, 64, 4, 8, 4, 64), mlp__nlayers=1, mlp__optimizer__learning_rate=0.0001;, score=(train=0.369, test=0.466) total time=   5.2s
# [CV 1/5] END mlp__dropouts=[0.2 0.  0.3 0.3 0.3 0.2], mlp__hiddens=(32, 32, 4, 64, 8, 4), mlp__nlayers=5, mlp__optimizer__learning_rate=0.005;, score=(train=0.617, test=0.480) total time=   1.7s
# [CV 2/5] END mlp__dropouts=[0.2 0.  0.3 0.3 0.3 0.2], mlp__hiddens=(32, 32, 4, 64, 8, 4), mlp__nlayers=5, mlp__optimizer__learning_rate=0.005;, score=(train=0.165, test=-0.048) total time=   1.3s
# [CV 3/5] END mlp__dropouts=[0.2 0.  0.3 0.3 0.3 0.2], mlp__hiddens=(32, 32, 4, 64, 8, 4), mlp__nlayers=5, mlp__optimizer__learning_rate=0.005;, score=(train=0.150, test=0.090) total time=   1.3s
# [CV 4/5] END mlp__dropouts=[0.2 0.  0.3 0.3 0.3 0.2], mlp__hiddens=(32, 32, 4, 64, 8, 4), mlp__nlayers=5, mlp__optimizer__learning_rate=0.005;, score=(train=0.650, test=0.618) total time=   1.8s
# [CV 5/5] END mlp__dropouts=[0.2 0.  0.3 0.3 0.3 0.2], mlp__hiddens=(32, 32, 4, 64, 8, 4), mlp__nlayers=5, mlp__optimizer__learning_rate=0.005;, score=(train=0.150, test=0.211) total time=   1.3s
# [CV 1/5] END mlp__dropouts=[0.  0.3 0.2 0.2 0.2 0.1], mlp__hiddens=(8, 16, 16, 16, 64, 16), mlp__nlayers=5, mlp__optimizer__learning_rate=0.001;, score=(train=0.444, test=0.357) total time=   2.1s
# [CV 2/5] END mlp__dropouts=[0.  0.3 0.2 0.2 0.2 0.1], mlp__hiddens=(8, 16, 16, 16, 64, 16), mlp__nlayers=5, mlp__optimizer__learning_rate=0.001;, score=(train=-0.032, test=-0.167) total time=   1.5s
# [CV 3/5] END mlp__dropouts=[0.  0.3 0.2 0.2 0.2 0.1], mlp__hiddens=(8, 16, 16, 16, 64, 16), mlp__nlayers=5, mlp__optimizer__learning_rate=0.001;, score=(train=-0.012, test=-0.271) total time=   1.5s
# [CV 4/5] END mlp__dropouts=[0.  0.3 0.2 0.2 0.2 0.1], mlp__hiddens=(8, 16, 16, 16, 64, 16), mlp__nlayers=5, mlp__optimizer__learning_rate=0.001;, score=(train=0.414, test=0.397) total time=   2.0s
# [CV 5/5] END mlp__dropouts=[0.  0.3 0.2 0.2 0.2 0.1], mlp__hiddens=(8, 16, 16, 16, 64, 16), mlp__nlayers=5, mlp__optimizer__learning_rate=0.001;, score=(train=0.377, test=0.329) total time=   2.0s
# [CV 1/5] END mlp__dropouts=[0.3 0.  0.  0.  0.  0. ], mlp__hiddens=(16, 16, 64, 8, 4, 16), mlp__nlayers=1, mlp__optimizer__learning_rate=0.0001;, score=(train=0.198, test=0.102) total time=   5.2s
# [CV 2/5] END mlp__dropouts=[0.3 0.  0.  0.  0.  0. ], mlp__hiddens=(16, 16, 64, 8, 4, 16), mlp__nlayers=1, mlp__optimizer__learning_rate=0.0001;, score=(train=0.210, test=-0.025) total time=   5.2s
# [CV 3/5] END mlp__dropouts=[0.3 0.  0.  0.  0.  0. ], mlp__hiddens=(16, 16, 64, 8, 4, 16), mlp__nlayers=1, mlp__optimizer__learning_rate=0.0001;, score=(train=0.204, test=0.120) total time=   5.2s
# [CV 4/5] END mlp__dropouts=[0.3 0.  0.  0.  0.  0. ], mlp__hiddens=(16, 16, 64, 8, 4, 16), mlp__nlayers=1, mlp__optimizer__learning_rate=0.0001;, score=(train=0.185, test=0.199) total time=   5.2s
# [CV 5/5] END mlp__dropouts=[0.3 0.  0.  0.  0.  0. ], mlp__hiddens=(16, 16, 64, 8, 4, 16), mlp__nlayers=1, mlp__optimizer__learning_rate=0.0001;, score=(train=0.220, test=0.308) total time=   5.2s
# [CV 1/5] END mlp__dropouts=[0.1 0.  0.  0.  0.2 0.3], mlp__hiddens=(4, 4, 32, 32, 16, 16), mlp__nlayers=4, mlp__optimizer__learning_rate=0.005;, score=(train=0.759, test=0.675) total time=   1.5s
# [CV 2/5] END mlp__dropouts=[0.1 0.  0.  0.  0.2 0.3], mlp__hiddens=(4, 4, 32, 32, 16, 16), mlp__nlayers=4, mlp__optimizer__learning_rate=0.005;, score=(train=0.702, test=0.691) total time=   1.5s
# [CV 3/5] END mlp__dropouts=[0.1 0.  0.  0.  0.2 0.3], mlp__hiddens=(4, 4, 32, 32, 16, 16), mlp__nlayers=4, mlp__optimizer__learning_rate=0.005;, score=(train=0.724, test=0.716) total time=   1.4s
# [CV 4/5] END mlp__dropouts=[0.1 0.  0.  0.  0.2 0.3], mlp__hiddens=(4, 4, 32, 32, 16, 16), mlp__nlayers=4, mlp__optimizer__learning_rate=0.005;, score=(train=0.724, test=0.717) total time=   1.4s
# [CV 5/5] END mlp__dropouts=[0.1 0.  0.  0.  0.2 0.3], mlp__hiddens=(4, 4, 32, 32, 16, 16), mlp__nlayers=4, mlp__optimizer__learning_rate=0.005;, score=(train=0.752, test=0.733) total time=   1.5s
# [CV 1/5] END mlp__dropouts=[0.3 0.2 0.1 0.1 0.3 0.1], mlp__hiddens=(64, 32, 16, 64, 32, 64), mlp__nlayers=5, mlp__optimizer__learning_rate=0.005;, score=(train=0.630, test=0.604) total time=   1.3s
# [CV 2/5] END mlp__dropouts=[0.3 0.2 0.1 0.1 0.3 0.1], mlp__hiddens=(64, 32, 16, 64, 32, 64), mlp__nlayers=5, mlp__optimizer__learning_rate=0.005;, score=(train=0.673, test=0.521) total time=   1.3s
# [CV 3/5] END mlp__dropouts=[0.3 0.2 0.1 0.1 0.3 0.1], mlp__hiddens=(64, 32, 16, 64, 32, 64), mlp__nlayers=5, mlp__optimizer__learning_rate=0.005;, score=(train=0.475, test=0.310) total time=   1.3s
# [CV 4/5] END mlp__dropouts=[0.3 0.2 0.1 0.1 0.3 0.1], mlp__hiddens=(64, 32, 16, 64, 32, 64), mlp__nlayers=5, mlp__optimizer__learning_rate=0.005;, score=(train=0.594, test=0.583) total time=   1.3s
# [CV 5/5] END mlp__dropouts=[0.3 0.2 0.1 0.1 0.3 0.1], mlp__hiddens=(64, 32, 16, 64, 32, 64), mlp__nlayers=5, mlp__optimizer__learning_rate=0.005;, score=(train=0.735, test=0.662) total time=   1.6s
# [CV 1/5] END mlp__dropouts=[0.  0.3 0.3 0.3 0.1 0. ], mlp__hiddens=(8, 32, 32, 16, 8, 64), mlp__nlayers=4, mlp__optimizer__learning_rate=0.005;, score=(train=0.737, test=0.619) total time=   1.4s
# [CV 2/5] END mlp__dropouts=[0.  0.3 0.3 0.3 0.1 0. ], mlp__hiddens=(8, 32, 32, 16, 8, 64), mlp__nlayers=4, mlp__optimizer__learning_rate=0.005;, score=(train=0.723, test=0.653) total time=   1.7s
# [CV 3/5] END mlp__dropouts=[0.  0.3 0.3 0.3 0.1 0. ], mlp__hiddens=(8, 32, 32, 16, 8, 64), mlp__nlayers=4, mlp__optimizer__learning_rate=0.005;, score=(train=0.759, test=0.675) total time=   1.6s
# [CV 4/5] END mlp__dropouts=[0.  0.3 0.3 0.3 0.1 0. ], mlp__hiddens=(8, 32, 32, 16, 8, 64), mlp__nlayers=4, mlp__optimizer__learning_rate=0.005;, score=(train=0.711, test=0.676) total time=   1.4s
# [CV 5/5] END mlp__dropouts=[0.  0.3 0.3 0.3 0.1 0. ], mlp__hiddens=(8, 32, 32, 16, 8, 64), mlp__nlayers=4, mlp__optimizer__learning_rate=0.005;, score=(train=0.702, test=0.682) total time=   1.4s
# [CV 1/5] END mlp__dropouts=[0.  0.  0.2 0.2 0.3 0. ], mlp__hiddens=(16, 64, 64, 8, 16, 16), mlp__nlayers=4, mlp__optimizer__learning_rate=0.001;, score=(train=0.741, test=0.616) total time=   1.8s
# [CV 2/5] END mlp__dropouts=[0.  0.  0.2 0.2 0.3 0. ], mlp__hiddens=(16, 64, 64, 8, 16, 16), mlp__nlayers=4, mlp__optimizer__learning_rate=0.001;, score=(train=0.487, test=0.316) total time=   1.3s
# [CV 3/5] END mlp__dropouts=[0.  0.  0.2 0.2 0.3 0. ], mlp__hiddens=(16, 64, 64, 8, 16, 16), mlp__nlayers=4, mlp__optimizer__learning_rate=0.001;, score=(train=0.615, test=0.476) total time=   1.4s
# [CV 4/5] END mlp__dropouts=[0.  0.  0.2 0.2 0.3 0. ], mlp__hiddens=(16, 64, 64, 8, 16, 16), mlp__nlayers=4, mlp__optimizer__learning_rate=0.001;, score=(train=0.672, test=0.641) total time=   1.6s
# [CV 5/5] END mlp__dropouts=[0.  0.  0.2 0.2 0.3 0. ], mlp__hiddens=(16, 64, 64, 8, 16, 16), mlp__nlayers=4, mlp__optimizer__learning_rate=0.001;, score=(train=0.690, test=0.673) total time=   1.7s
# [CV 1/5] END mlp__dropouts=[0.2 0.  0.3 0.3 0.2 0. ], mlp__hiddens=(4, 8, 8, 16, 4, 16), mlp__nlayers=2, mlp__optimizer__learning_rate=0.001;, score=(train=0.715, test=0.587) total time=   3.4s
# [CV 2/5] END mlp__dropouts=[0.2 0.  0.3 0.3 0.2 0. ], mlp__hiddens=(4, 8, 8, 16, 4, 16), mlp__nlayers=2, mlp__optimizer__learning_rate=0.001;, score=(train=0.651, test=0.633) total time=   2.8s
# [CV 3/5] END mlp__dropouts=[0.2 0.  0.3 0.3 0.2 0. ], mlp__hiddens=(4, 8, 8, 16, 4, 16), mlp__nlayers=2, mlp__optimizer__learning_rate=0.001;, score=(train=0.679, test=0.634) total time=   3.0s
# [CV 4/5] END mlp__dropouts=[0.2 0.  0.3 0.3 0.2 0. ], mlp__hiddens=(4, 8, 8, 16, 4, 16), mlp__nlayers=2, mlp__optimizer__learning_rate=0.001;, score=(train=0.625, test=0.631) total time=   2.9s
# [CV 5/5] END mlp__dropouts=[0.2 0.  0.3 0.3 0.2 0. ], mlp__hiddens=(4, 8, 8, 16, 4, 16), mlp__nlayers=2, mlp__optimizer__learning_rate=0.001;, score=(train=0.681, test=0.652) total time=   3.2s
# [CV 1/5] END mlp__dropouts=[0.1 0.2 0.1 0.  0.2 0.3], mlp__hiddens=(32, 8, 64, 16, 32, 64), mlp__nlayers=6, mlp__optimizer__learning_rate=0.005;, score=(train=0.757, test=0.612) total time=   1.6s
# [CV 2/5] END mlp__dropouts=[0.1 0.2 0.1 0.  0.2 0.3], mlp__hiddens=(32, 8, 64, 16, 32, 64), mlp__nlayers=6, mlp__optimizer__learning_rate=0.005;, score=(train=0.624, test=0.495) total time=   1.5s
# [CV 3/5] END mlp__dropouts=[0.1 0.2 0.1 0.  0.2 0.3], mlp__hiddens=(32, 8, 64, 16, 32, 64), mlp__nlayers=6, mlp__optimizer__learning_rate=0.005;, score=(train=0.739, test=0.691) total time=   1.7s
# [CV 4/5] END mlp__dropouts=[0.1 0.2 0.1 0.  0.2 0.3], mlp__hiddens=(32, 8, 64, 16, 32, 64), mlp__nlayers=6, mlp__optimizer__learning_rate=0.005;, score=(train=0.696, test=0.643) total time=   1.5s
# [CV 5/5] END mlp__dropouts=[0.1 0.2 0.1 0.  0.2 0.3], mlp__hiddens=(32, 8, 64, 16, 32, 64), mlp__nlayers=6, mlp__optimizer__learning_rate=0.005;, score=(train=0.729, test=0.727) total time=   1.5s
# [CV 1/5] END mlp__dropouts=[0.2 0.2 0.3 0.  0.3 0. ], mlp__hiddens=(32, 4, 8, 16, 8, 16), mlp__nlayers=4, mlp__optimizer__learning_rate=0.0001;, score=(train=0.208, test=0.164) total time=   3.7s
# [CV 2/5] END mlp__dropouts=[0.2 0.2 0.3 0.  0.3 0. ], mlp__hiddens=(32, 4, 8, 16, 8, 16), mlp__nlayers=4, mlp__optimizer__learning_rate=0.0001;, score=(train=0.186, test=0.151) total time=   3.9s
# [CV 3/5] END mlp__dropouts=[0.2 0.2 0.3 0.  0.3 0. ], mlp__hiddens=(32, 4, 8, 16, 8, 16), mlp__nlayers=4, mlp__optimizer__learning_rate=0.0001;, score=(train=0.171, test=0.099) total time=   3.7s
# [CV 4/5] END mlp__dropouts=[0.2 0.2 0.3 0.  0.3 0. ], mlp__hiddens=(32, 4, 8, 16, 8, 16), mlp__nlayers=4, mlp__optimizer__learning_rate=0.0001;, score=(train=0.156, test=-0.073) total time=   4.0s
# [CV 5/5] END mlp__dropouts=[0.2 0.2 0.3 0.  0.3 0. ], mlp__hiddens=(32, 4, 8, 16, 8, 16), mlp__nlayers=4, mlp__optimizer__learning_rate=0.0001;, score=(train=0.139, test=0.209) total time=   3.7s
# [CV 1/5] END mlp__dropouts=[0.  0.3 0.  0.3 0.1 0. ], mlp__hiddens=(8, 16, 8, 4, 32, 8), mlp__nlayers=5, mlp__optimizer__learning_rate=0.001;, score=(train=0.542, test=0.460) total time=   2.0s
# [CV 2/5] END mlp__dropouts=[0.  0.3 0.  0.3 0.1 0. ], mlp__hiddens=(8, 16, 8, 4, 32, 8), mlp__nlayers=5, mlp__optimizer__learning_rate=0.001;, score=(train=0.556, test=0.571) total time=   2.4s
# [CV 3/5] END mlp__dropouts=[0.  0.3 0.  0.3 0.1 0. ], mlp__hiddens=(8, 16, 8, 4, 32, 8), mlp__nlayers=5, mlp__optimizer__learning_rate=0.001;, score=(train=0.460, test=0.339) total time=   1.8s
# [CV 4/5] END mlp__dropouts=[0.  0.3 0.  0.3 0.1 0. ], mlp__hiddens=(8, 16, 8, 4, 32, 8), mlp__nlayers=5, mlp__optimizer__learning_rate=0.001;, score=(train=0.604, test=0.571) total time=   2.1s
# [CV 5/5] END mlp__dropouts=[0.  0.3 0.  0.3 0.1 0. ], mlp__hiddens=(8, 16, 8, 4, 32, 8), mlp__nlayers=5, mlp__optimizer__learning_rate=0.001;, score=(train=0.404, test=0.391) total time=   1.8s
# [CV 1/5] END mlp__dropouts=[0.3 0.  0.  0.2 0.  0.1], mlp__hiddens=(32, 8, 64, 4, 16, 16), mlp__nlayers=5, mlp__optimizer__learning_rate=0.001;, score=(train=0.577, test=0.477) total time=   1.5s
# [CV 2/5] END mlp__dropouts=[0.3 0.  0.  0.2 0.  0.1], mlp__hiddens=(32, 8, 64, 4, 16, 16), mlp__nlayers=5, mlp__optimizer__learning_rate=0.001;, score=(train=0.538, test=0.410) total time=   1.6s
# [CV 3/5] END mlp__dropouts=[0.3 0.  0.  0.2 0.  0.1], mlp__hiddens=(32, 8, 64, 4, 16, 16), mlp__nlayers=5, mlp__optimizer__learning_rate=0.001;, score=(train=0.621, test=0.539) total time=   1.6s
# [CV 4/5] END mlp__dropouts=[0.3 0.  0.  0.2 0.  0.1], mlp__hiddens=(32, 8, 64, 4, 16, 16), mlp__nlayers=5, mlp__optimizer__learning_rate=0.001;, score=(train=0.566, test=0.507) total time=   2.0s
# [CV 5/5] END mlp__dropouts=[0.3 0.  0.  0.2 0.  0.1], mlp__hiddens=(32, 8, 64, 4, 16, 16), mlp__nlayers=5, mlp__optimizer__learning_rate=0.001;, score=(train=0.588, test=0.577) total time=   1.8s
# [CV 1/5] END mlp__dropouts=[0.  0.  0.1 0.1 0.3 0.3], mlp__hiddens=(64, 64, 32, 16, 32, 8), mlp__nlayers=6, mlp__optimizer__learning_rate=0.0001;, score=(train=0.296, test=0.287) total time=   2.6s
# [CV 2/5] END mlp__dropouts=[0.  0.  0.1 0.1 0.3 0.3], mlp__hiddens=(64, 64, 32, 16, 32, 8), mlp__nlayers=6, mlp__optimizer__learning_rate=0.0001;, score=(train=0.222, test=0.161) total time=   2.5s
# [CV 3/5] END mlp__dropouts=[0.  0.  0.1 0.1 0.3 0.3], mlp__hiddens=(64, 64, 32, 16, 32, 8), mlp__nlayers=6, mlp__optimizer__learning_rate=0.0001;, score=(train=0.218, test=0.061) total time=   2.4s
# [CV 4/5] END mlp__dropouts=[0.  0.  0.1 0.1 0.3 0.3], mlp__hiddens=(64, 64, 32, 16, 32, 8), mlp__nlayers=6, mlp__optimizer__learning_rate=0.0001;, score=(train=0.232, test=0.106) total time=   2.4s
# [CV 5/5] END mlp__dropouts=[0.  0.  0.1 0.1 0.3 0.3], mlp__hiddens=(64, 64, 32, 16, 32, 8), mlp__nlayers=6, mlp__optimizer__learning_rate=0.0001;, score=(train=0.189, test=0.250) total time=   2.4s
# [CV 1/5] END mlp__dropouts=[0.1 0.1 0.  0.2 0.  0.3], mlp__hiddens=(32, 4, 32, 32, 8, 64), mlp__nlayers=6, mlp__optimizer__learning_rate=0.005;, score=(train=0.778, test=0.651) total time=   1.5s
# [CV 2/5] END mlp__dropouts=[0.1 0.1 0.  0.2 0.  0.3], mlp__hiddens=(32, 4, 32, 32, 8, 64), mlp__nlayers=6, mlp__optimizer__learning_rate=0.005;, score=(train=0.692, test=0.639) total time=   1.4s
# [CV 3/5] END mlp__dropouts=[0.1 0.1 0.  0.2 0.  0.3], mlp__hiddens=(32, 4, 32, 32, 8, 64), mlp__nlayers=6, mlp__optimizer__learning_rate=0.005;, score=(train=0.710, test=0.702) total time=   1.8s
# [CV 4/5] END mlp__dropouts=[0.1 0.1 0.  0.2 0.  0.3], mlp__hiddens=(32, 4, 32, 32, 8, 64), mlp__nlayers=6, mlp__optimizer__learning_rate=0.005;, score=(train=0.751, test=0.696) total time=   1.5s
# [CV 5/5] END mlp__dropouts=[0.1 0.1 0.  0.2 0.  0.3], mlp__hiddens=(32, 4, 32, 32, 8, 64), mlp__nlayers=6, mlp__optimizer__learning_rate=0.005;, score=(train=0.750, test=0.713) total time=   1.5s
# [CV 1/5] END mlp__dropouts=[0.  0.  0.3 0.2 0.1 0.2], mlp__hiddens=(64, 32, 8, 8, 8, 4), mlp__nlayers=5, mlp__optimizer__learning_rate=0.001;, score=(train=0.549, test=0.447) total time=   1.7s
# [CV 2/5] END mlp__dropouts=[0.  0.  0.3 0.2 0.1 0.2], mlp__hiddens=(64, 32, 8, 8, 8, 4), mlp__nlayers=5, mlp__optimizer__learning_rate=0.001;, score=(train=0.548, test=0.424) total time=   1.7s
# [CV 3/5] END mlp__dropouts=[0.  0.  0.3 0.2 0.1 0.2], mlp__hiddens=(64, 32, 8, 8, 8, 4), mlp__nlayers=5, mlp__optimizer__learning_rate=0.001;, score=(train=0.351, test=0.207) total time=   1.4s
# [CV 4/5] END mlp__dropouts=[0.  0.  0.3 0.2 0.1 0.2], mlp__hiddens=(64, 32, 8, 8, 8, 4), mlp__nlayers=5, mlp__optimizer__learning_rate=0.001;, score=(train=0.518, test=0.450) total time=   1.4s
# [CV 5/5] END mlp__dropouts=[0.  0.  0.3 0.2 0.1 0.2], mlp__hiddens=(64, 32, 8, 8, 8, 4), mlp__nlayers=5, mlp__optimizer__learning_rate=0.001;, score=(train=0.485, test=0.461) total time=   1.6s
# [CV 1/5] END mlp__dropouts=[0.  0.2 0.3 0.3 0.  0. ], mlp__hiddens=(8, 4, 16, 64, 8, 16), mlp__nlayers=4, mlp__optimizer__learning_rate=0.001;, score=(train=0.535, test=0.491) total time=   1.7s
# [CV 2/5] END mlp__dropouts=[0.  0.2 0.3 0.3 0.  0. ], mlp__hiddens=(8, 4, 16, 64, 8, 16), mlp__nlayers=4, mlp__optimizer__learning_rate=0.001;, score=(train=0.532, test=0.495) total time=   1.9s
# [CV 3/5] END mlp__dropouts=[0.  0.2 0.3 0.3 0.  0. ], mlp__hiddens=(8, 4, 16, 64, 8, 16), mlp__nlayers=4, mlp__optimizer__learning_rate=0.001;, score=(train=0.501, test=0.320) total time=   1.8s
# [CV 4/5] END mlp__dropouts=[0.  0.2 0.3 0.3 0.  0. ], mlp__hiddens=(8, 4, 16, 64, 8, 16), mlp__nlayers=4, mlp__optimizer__learning_rate=0.001;, score=(train=0.458, test=0.331) total time=   1.7s
# [CV 5/5] END mlp__dropouts=[0.  0.2 0.3 0.3 0.  0. ], mlp__hiddens=(8, 4, 16, 64, 8, 16), mlp__nlayers=4, mlp__optimizer__learning_rate=0.001;, score=(train=0.486, test=0.484) total time=   1.7s
# [CV 1/5] END mlp__dropouts=[0.3 0.2 0.2 0.3 0.  0.2], mlp__hiddens=(8, 16, 16, 4, 4, 8), mlp__nlayers=3, mlp__optimizer__learning_rate=0.001;, score=(train=0.563, test=0.459) total time=   2.3s
# [CV 2/5] END mlp__dropouts=[0.3 0.2 0.2 0.3 0.  0.2], mlp__hiddens=(8, 16, 16, 4, 4, 8), mlp__nlayers=3, mlp__optimizer__learning_rate=0.001;, score=(train=0.534, test=0.496) total time=   2.2s
# [CV 3/5] END mlp__dropouts=[0.3 0.2 0.2 0.3 0.  0.2], mlp__hiddens=(8, 16, 16, 4, 4, 8), mlp__nlayers=3, mlp__optimizer__learning_rate=0.001;, score=(train=0.445, test=0.309) total time=   1.9s
# [CV 4/5] END mlp__dropouts=[0.3 0.2 0.2 0.3 0.  0.2], mlp__hiddens=(8, 16, 16, 4, 4, 8), mlp__nlayers=3, mlp__optimizer__learning_rate=0.001;, score=(train=0.404, test=0.382) total time=   1.8s
# [CV 5/5] END mlp__dropouts=[0.3 0.2 0.2 0.3 0.  0.2], mlp__hiddens=(8, 16, 16, 4, 4, 8), mlp__nlayers=3, mlp__optimizer__learning_rate=0.001;, score=(train=0.485, test=0.508) total time=   2.2s
# [CV 1/5] END mlp__dropouts=[0.3 0.  0.2 0.  0.  0.3], mlp__hiddens=(4, 16, 8, 4, 32, 16), mlp__nlayers=1, mlp__optimizer__learning_rate=0.0001;, score=(train=-3.474, test=-3.644) total time=   5.2s
# [CV 2/5] END mlp__dropouts=[0.3 0.  0.2 0.  0.  0.3], mlp__hiddens=(4, 16, 8, 4, 32, 16), mlp__nlayers=1, mlp__optimizer__learning_rate=0.0001;, score=(train=-3.415, test=-4.336) total time=   5.2s
# [CV 3/5] END mlp__dropouts=[0.3 0.  0.2 0.  0.  0.3], mlp__hiddens=(4, 16, 8, 4, 32, 16), mlp__nlayers=1, mlp__optimizer__learning_rate=0.0001;, score=(train=-3.562, test=-3.209) total time=   5.2s
# [CV 4/5] END mlp__dropouts=[0.3 0.  0.2 0.  0.  0.3], mlp__hiddens=(4, 16, 8, 4, 32, 16), mlp__nlayers=1, mlp__optimizer__learning_rate=0.0001;, score=(train=-3.619, test=-3.718) total time=   5.2s
# [CV 5/5] END mlp__dropouts=[0.3 0.  0.2 0.  0.  0.3], mlp__hiddens=(4, 16, 8, 4, 32, 16), mlp__nlayers=1, mlp__optimizer__learning_rate=0.0001;, score=(train=-3.638, test=-3.322) total time=   5.4s
# [CV 1/5] END mlp__dropouts=[0.  0.3 0.3 0.2 0.  0.2], mlp__hiddens=(64, 32, 4, 8, 16, 64), mlp__nlayers=6, mlp__optimizer__learning_rate=0.0001;, score=(train=-0.114, test=-0.107) total time=   2.5s
# [CV 2/5] END mlp__dropouts=[0.  0.3 0.3 0.2 0.  0.2], mlp__hiddens=(64, 32, 4, 8, 16, 64), mlp__nlayers=6, mlp__optimizer__learning_rate=0.0001;, score=(train=-0.211, test=-0.334) total time=   2.6s
# [CV 3/5] END mlp__dropouts=[0.  0.3 0.3 0.2 0.  0.2], mlp__hiddens=(64, 32, 4, 8, 16, 64), mlp__nlayers=6, mlp__optimizer__learning_rate=0.0001;, score=(train=-0.178, test=-0.265) total time=   2.5s
# [CV 4/5] END mlp__dropouts=[0.  0.3 0.3 0.2 0.  0.2], mlp__hiddens=(64, 32, 4, 8, 16, 64), mlp__nlayers=6, mlp__optimizer__learning_rate=0.0001;, score=(train=-0.097, test=-0.249) total time=   2.8s
# [CV 5/5] END mlp__dropouts=[0.  0.3 0.3 0.2 0.  0.2], mlp__hiddens=(64, 32, 4, 8, 16, 64), mlp__nlayers=6, mlp__optimizer__learning_rate=0.0001;, score=(train=-0.153, test=-0.114) total time=   2.5s
# [CV 1/5] END mlp__dropouts=[0.  0.  0.3 0.  0.1 0.1], mlp__hiddens=(64, 64, 8, 4, 64, 16), mlp__nlayers=2, mlp__optimizer__learning_rate=0.001;, score=(train=0.765, test=0.634) total time=   1.4s
# [CV 2/5] END mlp__dropouts=[0.  0.  0.3 0.  0.1 0.1], mlp__hiddens=(64, 64, 8, 4, 64, 16), mlp__nlayers=2, mlp__optimizer__learning_rate=0.001;, score=(train=0.721, test=0.608) total time=   1.3s
# [CV 3/5] END mlp__dropouts=[0.  0.  0.3 0.  0.1 0.1], mlp__hiddens=(64, 64, 8, 4, 64, 16), mlp__nlayers=2, mlp__optimizer__learning_rate=0.001;, score=(train=0.727, test=0.642) total time=   1.3s
# [CV 4/5] END mlp__dropouts=[0.  0.  0.3 0.  0.1 0.1], mlp__hiddens=(64, 64, 8, 4, 64, 16), mlp__nlayers=2, mlp__optimizer__learning_rate=0.001;, score=(train=0.761, test=0.705) total time=   1.5s
# ...
# [CV 5/5] END mlp__dropouts=[0.  0.2 0.  0.1 0.  0. ], mlp__hiddens=(16, 32, 4, 4, 32, 64), mlp__nlayers=5, mlp__optimizer__learning_rate=0.001;, score=(train=0.699, test=0.706) total time=   1.8s
# [CV 1/5] END mlp__dropouts=[0.  0.  0.3 0.  0.3 0. ], mlp__hiddens=(16, 8, 4, 8, 16, 8), mlp__nlayers=1, mlp__optimizer__learning_rate=0.005;, score=(train=0.734, test=0.640) total time=   1.4s
# [CV 2/5] END mlp__dropouts=[0.  0.  0.3 0.  0.3 0. ], mlp__hiddens=(16, 8, 4, 8, 16, 8), mlp__nlayers=1, mlp__optimizer__learning_rate=0.005;, score=(train=0.776, test=0.638) total time=   1.5s
# [CV 3/5] END mlp__dropouts=[0.  0.  0.3 0.  0.3 0. ], mlp__hiddens=(16, 8, 4, 8, 16, 8), mlp__nlayers=1, mlp__optimizer__learning_rate=0.005;, score=(train=0.725, test=0.647) total time=   1.3s
# [CV 4/5] END mlp__dropouts=[0.  0.  0.3 0.  0.3 0. ], mlp__hiddens=(16, 8, 4, 8, 16, 8), mlp__nlayers=1, mlp__optimizer__learning_rate=0.005;, score=(train=0.741, test=0.674) total time=   1.4s
# [CV 5/5] END mlp__dropouts=[0.  0.  0.3 0.  0.3 0. ], mlp__hiddens=(16, 8, 4, 8, 16, 8), mlp__nlayers=1, mlp__optimizer__learning_rate=0.005;, score=(train=0.748, test=0.700) total time=   1.4s
# [CV 1/5] END mlp__dropouts=[0.  0.3 0.2 0.  0.2 0.2], mlp__hiddens=(8, 32, 4, 8, 32, 8), mlp__nlayers=1, mlp__optimizer__learning_rate=0.005;, score=(train=0.770, test=0.627) total time=   1.9s
# [CV 2/5] END mlp__dropouts=[0.  0.3 0.2 0.  0.2 0.2], mlp__hiddens=(8, 32, 4, 8, 32, 8), mlp__nlayers=1, mlp__optimizer__learning_rate=0.005;, score=(train=0.735, test=0.639) total time=   1.7s
# [CV 3/5] END mlp__dropouts=[0.  0.3 0.2 0.  0.2 0.2], mlp__hiddens=(8, 32, 4, 8, 32, 8), mlp__nlayers=1, mlp__optimizer__learning_rate=0.005;, score=(train=0.753, test=0.652) total time=   2.0s
# [CV 4/5] END mlp__dropouts=[0.  0.3 0.2 0.  0.2 0.2], mlp__hiddens=(8, 32, 4, 8, 32, 8), mlp__nlayers=1, mlp__optimizer__learning_rate=0.005;, score=(train=0.760, test=0.730) total time=   1.8s
# [CV 5/5] END mlp__dropouts=[0.  0.3 0.2 0.  0.2 0.2], mlp__hiddens=(8, 32, 4, 8, 32, 8), mlp__nlayers=1, mlp__optimizer__learning_rate=0.005;, score=(train=0.701, test=0.678) total time=   1.5s
# [CV 1/5] END mlp__dropouts=[0.3 0.  0.  0.  0.  0. ], mlp__hiddens=(8, 64, 8, 16, 8, 4), mlp__nlayers=5, mlp__optimizer__learning_rate=0.0001;, score=(train=0.489, test=0.429) total time=   5.7s
# [CV 2/5] END mlp__dropouts=[0.3 0.  0.  0.  0.  0. ], mlp__hiddens=(8, 64, 8, 16, 8, 4), mlp__nlayers=5, mlp__optimizer__learning_rate=0.0001;, score=(train=0.216, test=0.148) total time=   4.4s
# [CV 3/5] END mlp__dropouts=[0.3 0.  0.  0.  0.  0. ], mlp__hiddens=(8, 64, 8, 16, 8, 4), mlp__nlayers=5, mlp__optimizer__learning_rate=0.0001;, score=(train=0.329, test=0.086) total time=   4.5s
# [CV 4/5] END mlp__dropouts=[0.3 0.  0.  0.  0.  0. ], mlp__hiddens=(8, 64, 8, 16, 8, 4), mlp__nlayers=5, mlp__optimizer__learning_rate=0.0001;, score=(train=0.118, test=0.089) total time=   4.1s
# [CV 5/5] END mlp__dropouts=[0.3 0.  0.  0.  0.  0. ], mlp__hiddens=(8, 64, 8, 16, 8, 4), mlp__nlayers=5, mlp__optimizer__learning_rate=0.0001;, score=(train=0.084, test=0.119) total time=   4.2s
# [CV 1/5] END mlp__dropouts=[0.2 0.2 0.  0.  0.1 0.2], mlp__hiddens=(4, 16, 8, 8, 16, 4), mlp__nlayers=1, mlp__optimizer__learning_rate=0.0001;, score=(train=-3.431, test=-3.605) total time=   5.2s
# [CV 2/5] END mlp__dropouts=[0.2 0.2 0.  0.  0.1 0.2], mlp__hiddens=(4, 16, 8, 8, 16, 4), mlp__nlayers=1, mlp__optimizer__learning_rate=0.0001;, score=(train=-3.378, test=-4.293) total time=   5.2s
# [CV 3/5] END mlp__dropouts=[0.2 0.2 0.  0.  0.1 0.2], mlp__hiddens=(4, 16, 8, 8, 16, 4), mlp__nlayers=1, mlp__optimizer__learning_rate=0.0001;, score=(train=-3.526, test=-3.175) total time=   5.3s
# [CV 4/5] END mlp__dropouts=[0.2 0.2 0.  0.  0.1 0.2], mlp__hiddens=(4, 16, 8, 8, 16, 4), mlp__nlayers=1, mlp__optimizer__learning_rate=0.0001;, score=(train=-3.580, test=-3.682) total time=   5.3s
# [CV 5/5] END mlp__dropouts=[0.2 0.2 0.  0.  0.1 0.2], mlp__hiddens=(4, 16, 8, 8, 16, 4), mlp__nlayers=1, mlp__optimizer__learning_rate=0.0001;, score=(train=-3.604, test=-3.288) total time=   5.2s
# [CV 1/5] END mlp__dropouts=[0.  0.2 0.1 0.2 0.2 0.2], mlp__hiddens=(32, 4, 64, 4, 8, 4), mlp__nlayers=4, mlp__optimizer__learning_rate=0.0001;, score=(train=0.025, test=-0.040) total time=   3.6s
# [CV 2/5] END mlp__dropouts=[0.  0.2 0.1 0.2 0.2 0.2], mlp__hiddens=(32, 4, 64, 4, 8, 4), mlp__nlayers=4, mlp__optimizer__learning_rate=0.0001;, score=(train=0.194, test=0.112) total time=   5.3s
# [CV 3/5] END mlp__dropouts=[0.  0.2 0.1 0.2 0.2 0.2], mlp__hiddens=(32, 4, 64, 4, 8, 4), mlp__nlayers=4, mlp__optimizer__learning_rate=0.0001;, score=(train=0.150, test=0.096) total time=   4.9s
# [CV 4/5] END mlp__dropouts=[0.  0.2 0.1 0.2 0.2 0.2], mlp__hiddens=(32, 4, 64, 4, 8, 4), mlp__nlayers=4, mlp__optimizer__learning_rate=0.0001;, score=(train=0.059, test=-0.148) total time=   4.2s
# [CV 5/5] END mlp__dropouts=[0.  0.2 0.1 0.2 0.2 0.2], mlp__hiddens=(32, 4, 64, 4, 8, 4), mlp__nlayers=4, mlp__optimizer__learning_rate=0.0001;, score=(train=0.071, test=0.124) total time=   4.3s
# [CV 1/5] END mlp__dropouts=[0.1 0.  0.  0.  0.1 0.3], mlp__hiddens=(8, 32, 4, 4, 32, 16), mlp__nlayers=2, mlp__optimizer__learning_rate=0.001;, score=(train=0.725, test=0.630) total time=   2.0s
# [CV 2/5] END mlp__dropouts=[0.1 0.  0.  0.  0.1 0.3], mlp__hiddens=(8, 32, 4, 4, 32, 16), mlp__nlayers=2, mlp__optimizer__learning_rate=0.001;, score=(train=0.691, test=0.566) total time=   1.9s
# [CV 3/5] END mlp__dropouts=[0.1 0.  0.  0.  0.1 0.3], mlp__hiddens=(8, 32, 4, 4, 32, 16), mlp__nlayers=2, mlp__optimizer__learning_rate=0.001;, score=(train=0.610, test=0.481) total time=   1.6s
# [CV 4/5] END mlp__dropouts=[0.1 0.  0.  0.  0.1 0.3], mlp__hiddens=(8, 32, 4, 4, 32, 16), mlp__nlayers=2, mlp__optimizer__learning_rate=0.001;, score=(train=0.724, test=0.662) total time=   2.4s
# [CV 5/5] END mlp__dropouts=[0.1 0.  0.  0.  0.1 0.3], mlp__hiddens=(8, 32, 4, 4, 32, 16), mlp__nlayers=2, mlp__optimizer__learning_rate=0.001;, score=(train=0.688, test=0.692) total time=   1.9s
# [CV 1/5] END mlp__dropouts=[0.2 0.2 0.1 0.2 0.  0. ], mlp__hiddens=(32, 16, 32, 32, 32, 32), mlp__nlayers=2, mlp__optimizer__learning_rate=0.0001;, score=(train=0.667, test=0.577) total time=   5.4s
# [CV 2/5] END mlp__dropouts=[0.2 0.2 0.1 0.2 0.  0. ], mlp__hiddens=(32, 16, 32, 32, 32, 32), mlp__nlayers=2, mlp__optimizer__learning_rate=0.0001;, score=(train=0.582, test=0.442) total time=   3.7s
# [CV 3/5] END mlp__dropouts=[0.2 0.2 0.1 0.2 0.  0. ], mlp__hiddens=(32, 16, 32, 32, 32, 32), mlp__nlayers=2, mlp__optimizer__learning_rate=0.0001;, score=(train=0.568, test=0.476) total time=   3.5s
# [CV 4/5] END mlp__dropouts=[0.2 0.2 0.1 0.2 0.  0. ], mlp__hiddens=(32, 16, 32, 32, 32, 32), mlp__nlayers=2, mlp__optimizer__learning_rate=0.0001;, score=(train=0.560, test=0.504) total time=   4.1s
# [CV 5/5] END mlp__dropouts=[0.2 0.2 0.1 0.2 0.  0. ], mlp__hiddens=(32, 16, 32, 32, 32, 32), mlp__nlayers=2, mlp__optimizer__learning_rate=0.0001;, score=(train=0.583, test=0.624) total time=   3.9s
# [CV 1/5] END mlp__dropouts=[0.  0.  0.1 0.1 0.3 0.3], mlp__hiddens=(64, 64, 32, 64, 16, 64), mlp__nlayers=5, mlp__optimizer__learning_rate=0.001;, score=(train=0.728, test=0.619) total time=   1.6s
# [CV 2/5] END mlp__dropouts=[0.  0.  0.1 0.1 0.3 0.3], mlp__hiddens=(64, 64, 32, 64, 16, 64), mlp__nlayers=5, mlp__optimizer__learning_rate=0.001;, score=(train=0.722, test=0.618) total time=   1.6s
# [CV 3/5] END mlp__dropouts=[0.  0.  0.1 0.1 0.3 0.3], mlp__hiddens=(64, 64, 32, 64, 16, 64), mlp__nlayers=5, mlp__optimizer__learning_rate=0.001;, score=(train=0.729, test=0.631) total time=   1.6s
# [CV 4/5] END mlp__dropouts=[0.  0.  0.1 0.1 0.3 0.3], mlp__hiddens=(64, 64, 32, 64, 16, 64), mlp__nlayers=5, mlp__optimizer__learning_rate=0.001;, score=(train=0.745, test=0.686) total time=   1.7s
# [CV 5/5] END mlp__dropouts=[0.  0.  0.1 0.1 0.3 0.3], mlp__hiddens=(64, 64, 32, 64, 16, 64), mlp__nlayers=5, mlp__optimizer__learning_rate=0.001;, score=(train=0.715, test=0.671) total time=   1.6s
# [CV 1/5] END mlp__dropouts=[0.3 0.1 0.3 0.3 0.  0.2], mlp__hiddens=(8, 64, 4, 32, 32, 16), mlp__nlayers=2, mlp__optimizer__learning_rate=0.0001;, score=(train=0.460, test=0.390) total time=   5.5s
# [CV 2/5] END mlp__dropouts=[0.3 0.1 0.3 0.3 0.  0.2], mlp__hiddens=(8, 64, 4, 32, 32, 16), mlp__nlayers=2, mlp__optimizer__learning_rate=0.0001;, score=(train=0.374, test=0.290) total time=   5.3s
# [CV 3/5] END mlp__dropouts=[0.3 0.1 0.3 0.3 0.  0.2], mlp__hiddens=(8, 64, 4, 32, 32, 16), mlp__nlayers=2, mlp__optimizer__learning_rate=0.0001;, score=(train=0.460, test=0.279) total time=   5.6s
# [CV 4/5] END mlp__dropouts=[0.3 0.1 0.3 0.3 0.  0.2], mlp__hiddens=(8, 64, 4, 32, 32, 16), mlp__nlayers=2, mlp__optimizer__learning_rate=0.0001;, score=(train=0.241, test=0.206) total time=   4.6s
# [CV 5/5] END mlp__dropouts=[0.3 0.1 0.3 0.3 0.  0.2], mlp__hiddens=(8, 64, 4, 32, 32, 16), mlp__nlayers=2, mlp__optimizer__learning_rate=0.0001;, score=(train=0.354, test=0.401) total time=   5.2s
# [CV 1/5] END mlp__dropouts=[0.1 0.1 0.  0.1 0.3 0.2], mlp__hiddens=(16, 64, 32, 16, 64, 8), mlp__nlayers=1, mlp__optimizer__learning_rate=0.005;, score=(train=0.772, test=0.657) total time=   1.5s
# [CV 2/5] END mlp__dropouts=[0.1 0.1 0.  0.1 0.3 0.2], mlp__hiddens=(16, 64, 32, 16, 64, 8), mlp__nlayers=1, mlp__optimizer__learning_rate=0.005;, score=(train=0.738, test=0.630) total time=   1.4s
# [CV 3/5] END mlp__dropouts=[0.1 0.1 0.  0.1 0.3 0.2], mlp__hiddens=(16, 64, 32, 16, 64, 8), mlp__nlayers=1, mlp__optimizer__learning_rate=0.005;, score=(train=0.724, test=0.630) total time=   1.3s
# [CV 4/5] END mlp__dropouts=[0.1 0.1 0.  0.1 0.3 0.2], mlp__hiddens=(16, 64, 32, 16, 64, 8), mlp__nlayers=1, mlp__optimizer__learning_rate=0.005;, score=(train=0.706, test=0.648) total time=   1.3s
# [CV 5/5] END mlp__dropouts=[0.1 0.1 0.  0.1 0.3 0.2], mlp__hiddens=(16, 64, 32, 16, 64, 8), mlp__nlayers=1, mlp__optimizer__learning_rate=0.005;, score=(train=0.743, test=0.713) total time=   1.4s
# [CV 1/5] END mlp__dropouts=[0.  0.  0.  0.3 0.3 0.3], mlp__hiddens=(8, 16, 32, 16, 64, 64), mlp__nlayers=1, mlp__optimizer__learning_rate=0.0001;, score=(train=-2.237, test=-2.117) total time=   5.2s
# [CV 2/5] END mlp__dropouts=[0.  0.  0.  0.3 0.3 0.3], mlp__hiddens=(8, 16, 32, 16, 64, 64), mlp__nlayers=1, mlp__optimizer__learning_rate=0.0001;, score=(train=-1.898, test=-2.451) total time=   5.2s
# [CV 3/5] END mlp__dropouts=[0.  0.  0.  0.3 0.3 0.3], mlp__hiddens=(8, 16, 32, 16, 64, 64), mlp__nlayers=1, mlp__optimizer__learning_rate=0.0001;, score=(train=-2.242, test=-2.055) total time=   5.2s
# [CV 4/5] END mlp__dropouts=[0.  0.  0.  0.3 0.3 0.3], mlp__hiddens=(8, 16, 32, 16, 64, 64), mlp__nlayers=1, mlp__optimizer__learning_rate=0.0001;, score=(train=-2.249, test=-2.070) total time=   5.2s
# [CV 5/5] END mlp__dropouts=[0.  0.  0.  0.3 0.3 0.3], mlp__hiddens=(8, 16, 32, 16, 64, 64), mlp__nlayers=1, mlp__optimizer__learning_rate=0.0001;, score=(train=-2.058, test=-2.293) total time=   5.2s
# [CV 1/5] END mlp__dropouts=[0.  0.2 0.1 0.1 0.3 0. ], mlp__hiddens=(8, 16, 64, 4, 64, 64), mlp__nlayers=2, mlp__optimizer__learning_rate=0.005;, score=(train=0.765, test=0.651) total time=   1.6s
# [CV 2/5] END mlp__dropouts=[0.  0.2 0.1 0.1 0.3 0. ], mlp__hiddens=(8, 16, 64, 4, 64, 64), mlp__nlayers=2, mlp__optimizer__learning_rate=0.005;, score=(train=0.598, test=0.422) total time=   1.2s
# [CV 3/5] END mlp__dropouts=[0.  0.2 0.1 0.1 0.3 0. ], mlp__hiddens=(8, 16, 64, 4, 64, 64), mlp__nlayers=2, mlp__optimizer__learning_rate=0.005;, score=(train=0.678, test=0.561) total time=   1.5s
# [CV 4/5] END mlp__dropouts=[0.  0.2 0.1 0.1 0.3 0. ], mlp__hiddens=(8, 16, 64, 4, 64, 64), mlp__nlayers=2, mlp__optimizer__learning_rate=0.005;, score=(train=0.699, test=0.661) total time=   1.4s
# [CV 5/5] END mlp__dropouts=[0.  0.2 0.1 0.1 0.3 0. ], mlp__hiddens=(8, 16, 64, 4, 64, 64), mlp__nlayers=2, mlp__optimizer__learning_rate=0.005;, score=(train=0.735, test=0.719) total time=   1.5s
# [CV 1/5] END mlp__dropouts=[0.  0.1 0.1 0.3 0.  0. ], mlp__hiddens=(4, 32, 8, 4, 4, 8), mlp__nlayers=5, mlp__optimizer__learning_rate=0.001;, score=(train=0.455, test=0.381) total time=   1.9s
# [CV 2/5] END mlp__dropouts=[0.  0.1 0.1 0.3 0.  0. ], mlp__hiddens=(4, 32, 8, 4, 4, 8), mlp__nlayers=5, mlp__optimizer__learning_rate=0.001;, score=(train=0.502, test=0.462) total time=   1.9s
# [CV 3/5] END mlp__dropouts=[0.  0.1 0.1 0.3 0.  0. ], mlp__hiddens=(4, 32, 8, 4, 4, 8), mlp__nlayers=5, mlp__optimizer__learning_rate=0.001;, score=(train=0.613, test=0.547) total time=   2.2s
# [CV 4/5] END mlp__dropouts=[0.  0.1 0.1 0.3 0.  0. ], mlp__hiddens=(4, 32, 8, 4, 4, 8), mlp__nlayers=5, mlp__optimizer__learning_rate=0.001;, score=(train=0.426, test=0.445) total time=   1.9s
# [CV 5/5] END mlp__dropouts=[0.  0.1 0.1 0.3 0.  0. ], mlp__hiddens=(4, 32, 8, 4, 4, 8), mlp__nlayers=5, mlp__optimizer__learning_rate=0.001;, score=(train=0.577, test=0.587) total time=   2.3s
# [CV 1/5] END mlp__dropouts=[0.2 0.  0.1 0.  0.1 0.1], mlp__hiddens=(8, 8, 8, 4, 64, 64), mlp__nlayers=4, mlp__optimizer__learning_rate=0.005;, score=(train=0.753, test=0.655) total time=   1.5s
# [CV 2/5] END mlp__dropouts=[0.2 0.  0.1 0.  0.1 0.1], mlp__hiddens=(8, 8, 8, 4, 64, 64), mlp__nlayers=4, mlp__optimizer__learning_rate=0.005;, score=(train=0.736, test=0.677) total time=   1.5s
# [CV 3/5] END mlp__dropouts=[0.2 0.  0.1 0.  0.1 0.1], mlp__hiddens=(8, 8, 8, 4, 64, 64), mlp__nlayers=4, mlp__optimizer__learning_rate=0.005;, score=(train=0.721, test=0.713) total time=   1.4s
# [CV 4/5] END mlp__dropouts=[0.2 0.  0.1 0.  0.1 0.1], mlp__hiddens=(8, 8, 8, 4, 64, 64), mlp__nlayers=4, mlp__optimizer__learning_rate=0.005;, score=(train=0.753, test=0.709) total time=   1.8s
# [CV 5/5] END mlp__dropouts=[0.2 0.  0.1 0.  0.1 0.1], mlp__hiddens=(8, 8, 8, 4, 64, 64), mlp__nlayers=4, mlp__optimizer__learning_rate=0.005;, score=(train=0.732, test=0.728) total time=   1.4s
# [CV 1/5] END mlp__dropouts=[0.1 0.3 0.  0.  0.  0. ], mlp__hiddens=(16, 16, 4, 8, 4, 4), mlp__nlayers=5, mlp__optimizer__learning_rate=0.001;, score=(train=0.759, test=0.662) total time=   2.7s
# [CV 2/5] END mlp__dropouts=[0.1 0.3 0.  0.  0.  0. ], mlp__hiddens=(16, 16, 4, 8, 4, 4), mlp__nlayers=5, mlp__optimizer__learning_rate=0.001;, score=(train=0.640, test=0.549) total time=   1.8s
# [CV 3/5] END mlp__dropouts=[0.1 0.3 0.  0.  0.  0. ], mlp__hiddens=(16, 16, 4, 8, 4, 4), mlp__nlayers=5, mlp__optimizer__learning_rate=0.001;, score=(train=0.685, test=0.590) total time=   2.0s
# [CV 4/5] END mlp__dropouts=[0.1 0.3 0.  0.  0.  0. ], mlp__hiddens=(16, 16, 4, 8, 4, 4), mlp__nlayers=5, mlp__optimizer__learning_rate=0.001;, score=(train=0.616, test=0.572) total time=   1.9s
# [CV 5/5] END mlp__dropouts=[0.1 0.3 0.  0.  0.  0. ], mlp__hiddens=(16, 16, 4, 8, 4, 4), mlp__nlayers=5, mlp__optimizer__learning_rate=0.001;, score=(train=0.617, test=0.653) total time=   1.8s
# [CV 1/5] END mlp__dropouts=[0.3 0.2 0.  0.1 0.1 0.3], mlp__hiddens=(16, 4, 4, 32, 8, 16), mlp__nlayers=5, mlp__optimizer__learning_rate=0.001;, score=(train=0.572, test=0.526) total time=   2.4s
# [CV 2/5] END mlp__dropouts=[0.3 0.2 0.  0.1 0.1 0.3], mlp__hiddens=(16, 4, 4, 32, 8, 16), mlp__nlayers=5, mlp__optimizer__learning_rate=0.001;, score=(train=0.321, test=0.376) total time=   1.9s
# [CV 3/5] END mlp__dropouts=[0.3 0.2 0.  0.1 0.1 0.3], mlp__hiddens=(16, 4, 4, 32, 8, 16), mlp__nlayers=5, mlp__optimizer__learning_rate=0.001;, score=(train=0.619, test=0.577) total time=   2.4s
# [CV 4/5] END mlp__dropouts=[0.3 0.2 0.  0.1 0.1 0.3], mlp__hiddens=(16, 4, 4, 32, 8, 16), mlp__nlayers=5, mlp__optimizer__learning_rate=0.001;, score=(train=0.518, test=0.439) total time=   2.0s
# [CV 5/5] END mlp__dropouts=[0.3 0.2 0.  0.1 0.1 0.3], mlp__hiddens=(16, 4, 4, 32, 8, 16), mlp__nlayers=5, mlp__optimizer__learning_rate=0.001;, score=(train=0.205, test=0.143) total time=   2.0s
# Done!

# %%
results_mlp.to_csv("best_model_mlp.csv", index=False)

# %% [markdown]
# ## Plot

# %%
best_model = pd.read_csv("best_model_mlp.csv")
best_model.head(1).T
# Out:
#                                                                                      0
# mean_fit_time                                                                 1.407427
# std_fit_time                                                                  0.043111
# mean_score_time                                                               0.076033
# std_score_time                                                                0.000587
# param_mlp__optimizer__learning_rate                                              0.005
# param_mlp__nlayers                                                                   4
# param_mlp__hiddens                                              (4, 4, 32, 32, 16, 16)
# param_mlp__dropouts                                          [0.1 0.  0.  0.  0.2 0.3]
# params                               {'mlp__optimizer__learning_rate': 0.005, 'mlp_...
# split0_test_score                                                             0.675065
# split1_test_score                                                             0.690818
# split2_test_score                                                             0.715825
# split3_test_score                                                             0.716619
# split4_test_score                                                             0.732541
# mean_test_score                                                               0.706174
# std_test_score                                                                0.020499
# rank_test_score                                                                      1
# split0_train_score                                                            0.759356
# split1_train_score                                                            0.701878
# split2_train_score                                                            0.723712
# split3_train_score                                                            0.723733
# split4_train_score                                                            0.751891
# mean_train_score                                                              0.732114
# std_train_score                                                                0.02092

# %%
mlp = KerasRegressor(
    rp.n_layers_feed_forward, 
    epochs=200, 
    loss="mse",
    callbacks=[callback],
    validation_split=0.2,
    nlayers=3,
    dropouts=[0.1, 0., 0., 0.,],
    hiddens=(4, 4, 32, 32),
    verbose=1
)

# %%
preprocessing_pipe = Pipeline(
    [
        ('scaler', PowerTransformer()),
        ("principal_components", PCA(n_components=20, svd_solver = 'full')),
    ]
)
mlp = rp.n_layers_feed_forward(
    dropouts=[0.1, 0.0, 0.0, 0.0,],
    hiddens=(4, 4, 32, 32),
    nlayers=3,
    meta={"X_shape_":(0, 20)}
)
mlp.compile(optimizer=RMSprop(learning_rate=0.005), loss="mae")
mlp.summary()
# Out:
# Model: "sequential_508"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_2187 (Dense)          (None, 4)                 84
#
#  dropout_1012 (Dropout)      (None, 4)                 0
#
#  dense_2188 (Dense)          (None, 4)                 20
#
#  dense_2189 (Dense)          (None, 32)                160
#
#  dense_2190 (Dense)          (None, 1)                 33
#
# =================================================================
# Total params: 297
# Trainable params: 297
# Non-trainable params: 0
# _________________________________________________________________

# %%
new_df = preprocessing_pipe.fit_transform(df)

# %%
callback = EarlyStopping(
    monitor="val_loss",
    min_delta=0,
    patience=6,
    restore_best_weights=True,
)

mlp.fit(
    new_df, 
    y, 
    epochs=200, 
    validation_split=0.3, 
    verbose=0, 
    shuffle=True, 
    callbacks=[callback]
)

# %%
loss_history = mlp.history.history["loss"]
loss_history_val = mlp.history.history["val_loss"]
plt.plot(loss_history, label="Train")
plt.plot(loss_history_val, label="Validation")
plt.xlabel("Epoch")
#plt.yscale("log")
plt.ylabel("MAE")
plt.legend()
